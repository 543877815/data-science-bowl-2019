# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import xgboost as xgb
import catboost as cat
from xgboost import XGBClassifier, XGBRegressor
from xgboost import plot_importance
from catboost import CatBoostRegressor
from matplotlib import pyplot
import shap
import re

base_dir = 'data/'

import os
for dirname, _, filenames in os.walk(base_dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
from time import time
from tqdm import tqdm_notebook as tqdm
from collections import Counter
from scipy import stats
import lightgbm as lgb
from sklearn.metrics import cohen_kappa_score, mean_squared_error
from sklearn.model_selection import KFold, StratifiedKFold, GroupKFold
from sklearn.linear_model import LinearRegression
from bayes_opt import BayesianOptimization
from sklearn.metrics import mean_squared_error
from datetime import datetime
import gc
import json
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

pd.set_option('display.max_columns', 1000)
# Out:
# data/sample_submission.csv
# data/reduce_test.csv
# data/train_labels.csv
# data/test.csv
# data/reduce_train.csv
# data/train.csv
# data/specs.csv

# %%
def eval_qwk_lgb_regr(y_true, y_pred):
    """
    Fast cappa eval function for lgb.
    """
    dist = Counter(reduce_train['accuracy_group'])
    for k in dist:
        dist[k] /= len(reduce_train)
    reduce_train['accuracy_group'].hist()
    
    acum = 0
    bound = {}
    for i in range(3):
        acum += dist[i]
        bound[i] = np.percentile(y_pred, acum * 100)

    def classify(x):
        if x <= bound[0]:
            return 0
        elif x <= bound[1]:
            return 1
        elif x <= bound[2]:
            return 2
        else:
            return 3

    y_pred = np.array(list(map(classify, y_pred))).reshape(y_true.shape)

    return 'cappa', cohen_kappa_score(y_true, y_pred, weights='quadratic'), True

def cohenkappa(ypred, y):
    y = y.get_label().astype("int")
    ypred = ypred.reshape((4, -1)).argmax(axis = 0)
    loss = cohenkappascore(y, y_pred, weights = 'quadratic')
    return "cappa", loss, True

def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod(
            (datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
def read_data():
    print('Reading train.csv file....')
    train = pd.read_csv(base_dir + 'train.csv')
    print('Training.csv file have {} rows and {} columns'.format(train.shape[0], train.shape[1]))

    print('Reading test.csv file....')
    test = pd.read_csv(base_dir + 'test.csv')
    print('Test.csv file have {} rows and {} columns'.format(test.shape[0], test.shape[1]))

    print('Reading train_labels.csv file....')
    train_labels = pd.read_csv(base_dir + 'train_labels.csv')
    print('Train_labels.csv file have {} rows and {} columns'.format(train_labels.shape[0], train_labels.shape[1]))

    print('Reading specs.csv file....')
    specs = pd.read_csv(base_dir + 'specs.csv')
    print('Specs.csv file have {} rows and {} columns'.format(specs.shape[0], specs.shape[1]))

    print('Reading sample_submission.csv file....')
    sample_submission = pd.read_csv(base_dir + 'sample_submission.csv')
    print('Sample_submission.csv file have {} rows and {} columns'.format(sample_submission.shape[0], sample_submission.shape[1]))
    return train, test, train_labels, specs, sample_submission

# %%
def cnt_miss(df):
    cnt = 0
    for e in range(len(df)):
        x = df['event_data'].iloc[e]
        y = json.loads(x)['misses']
        cnt += y
    return cnt

def get_4020_acc(df,counter_dict):
    
    for e in ['Cauldron Filler (Assessment)','Bird Measurer (Assessment)','Mushroom Sorter (Assessment)','Chest Sorter (Assessment)']:
        
        Assess_4020 = df[(df.event_code == 4020) & (df.title==activities_map[e])]   
        true_attempts_ = Assess_4020['event_data'].str.contains('true').sum()
        false_attempts_ = Assess_4020['event_data'].str.contains('false').sum()

        measure_assess_accuracy_ = true_attempts_/(true_attempts_+false_attempts_) if (true_attempts_+false_attempts_) != 0 else 0
        counter_dict[e+"_4020_accuracy"] += (counter_dict[e+"_4020_accuracy"] + measure_assess_accuracy_) / 2.0
    
    return counter_dict

# %%
def encode_title(train, test, train_labels):
    # encode title
    train['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), train['title'], train['event_code']))
    test['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), test['title'], test['event_code']))
    all_title_event_code = list(set(train["title_event_code"].unique()).union(test["title_event_code"].unique()))
    
    train['type_world'] = list(map(lambda x, y: str(x) + '_' + str(y), train['type'], train['world']))
    test['type_world'] = list(map(lambda x, y: str(x) + '_' + str(y), test['type'], test['world']))
    all_type_world = list(set(train["type_world"].unique()).union(test["type_world"].unique()))
    
    # make a list with all the unique 'titles' from the train and test set
    list_of_user_activities = list(set(train['title'].unique()).union(set(test['title'].unique())))
    # make a list with all the unique 'event_code' from the train and test set
    list_of_event_code = list(set(train['event_code'].unique()).union(set(test['event_code'].unique())))
    list_of_event_id = list(set(train['event_id'].unique()).union(set(test['event_id'].unique())))
    # make a list with all the unique worlds from the train and test set
    list_of_worlds = list(set(train['world'].unique()).union(set(test['world'].unique())))
    # create a dictionary numerating the titles
    activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))
    activities_labels = dict(zip(np.arange(len(list_of_user_activities)), list_of_user_activities))
    activities_world = dict(zip(list_of_worlds, np.arange(len(list_of_worlds))))
    assess_titles = list(set(train[train['type'] == 'Assessment']['title'].value_counts().index).union(set(test[test['type'] == 'Assessment']['title'].value_counts().index)))
    # replace the text titles with the number titles from the dict
    train['title'] = train['title'].map(activities_map)
    test['title'] = test['title'].map(activities_map)
    train['world'] = train['world'].map(activities_world)
    test['world'] = test['world'].map(activities_world)
    train_labels['title'] = train_labels['title'].map(activities_map)
    win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
    # then, it set one element, the 'Bird Measurer (Assessment)' as 4110, 10 more than the rest
    win_code[activities_map['Bird Measurer (Assessment)']] = 4110
    # convert text into datetime
    train['timestamp'] = pd.to_datetime(train['timestamp'])
    test['timestamp'] = pd.to_datetime(test['timestamp'])
    
    
    return train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code, activities_map,all_type_world

# %%
def get_data(user_sample, test_set=False):
    '''
    The user_sample is a DataFrame from train or test where the only one 
    installation_id is filtered
    And the test_set parameter is related with the labels processing, that is only requered
    if test_set=False
    '''
    # Constants and parameters declaration
    last_activity = 0
    
    user_activities_count = {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
    
    assess_4020_acc_dict = {'Cauldron Filler (Assessment)_4020_accuracy':0,
                                'Mushroom Sorter (Assessment)_4020_accuracy':0,
                                'Bird Measurer (Assessment)_4020_accuracy':0,
                                'Chest Sorter (Assessment)_4020_accuracy':0 }
    
    game_time_dict = {'Clip_gametime':0, 'Game_gametime':0, 'Activity_gametime':0, 'Assessment_gametime':0}
    
    # new features: time spent in each activity
    last_session_time_sec = 0
    accuracy_groups = {0:0, 1:0, 2:0, 3:0}
    all_assessments = []
    accumulated_accuracy_group = 0
    accumulated_accuracy = 0
    accumulated_correct_attempts = 0 
    accumulated_uncorrect_attempts = 0
    accumulated_actions = 0
    
    # Newly added features
    accumulated_game_miss = 0
    Cauldron_Filler_4025 = 0
    mean_game_round = 0
    mean_game_duration = 0 
    mean_game_level = 0
    Assessment_mean_event_count = 0
    Game_mean_event_count = 0
    Activity_mean_event_count = 0
    chest_assessment_uncorrect_sum = 0
    
    counter = 0
    time_first_activity = float(user_sample['timestamp'].values[0])
    durations = []
    last_accuracy_title = {'acc_' + title: -1 for title in assess_titles}
    event_code_count: Dict[str, int] = {ev: 0 for ev in list_of_event_code}
    event_id_count: Dict[str, int] = {eve: 0 for eve in list_of_event_id}
    title_count: Dict[str, int] = {eve: 0 for eve in activities_labels.values()} 
    title_event_code_count: Dict[str, int] = {t_eve: 0 for t_eve in all_title_event_code}
    type_world_count: Dict[str, int] = {w_eve: 0 for w_eve in all_type_world}
        
    # last features
    sessions_count = 0
    
    # itarates through each session of one instalation_id
    for i, session in user_sample.groupby('game_session', sort=False):
        # i = game_session_id
        # session is a DataFrame that contain only one game_session
        
        # get some sessions information
        session_type = session['type'].iloc[0]
        session_title = session['title'].iloc[0]
        session_title_text = activities_labels[session_title]
                    
        if session_type=="Activity":
            Activity_mean_event_count = (Activity_mean_event_count + session['event_count'].iloc[-1])/2.0
            
        if session_type=="Game":
            
            Game_mean_event_count = (Game_mean_event_count + session['event_count'].iloc[-1])/2.0
            
            game_s = session[session.event_code == 2030]   
            misses_cnt = cnt_miss(game_s)
            accumulated_game_miss += misses_cnt
            
            try:
                game_round = json.loads(session['event_data'].iloc[-1])["round"]
                mean_game_round =  (mean_game_round + game_round)/2.0
            except:
                pass

            try:
                game_duration = json.loads(session['event_data'].iloc[-1])["duration"]
                mean_game_duration = (mean_game_duration + game_duration) /2.0
            except:
                pass
            
            try:
                game_level = json.loads(session['event_data'].iloc[-1])["level"]
                mean_game_level = (mean_game_level + game_level) /2.0
            except:
                pass
            
        # for each assessment, and only this kind off session, the features below are processed
        # and a register are generated
        if (session_type == 'Assessment') & (test_set or len(session)>1):
            # search for event_code 4100, that represents the assessments trial
            all_attempts = session.query(f'event_code == {win_code[session_title]}')
            # then, check the numbers of wins and the number of losses
            true_attempts = all_attempts['event_data'].str.contains('true').sum()
            false_attempts = all_attempts['event_data'].str.contains('false').sum()
            # copy a dict to use as feature template, it's initialized with some itens: 
            # {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
            features = user_activities_count.copy()
            features.update(last_accuracy_title.copy())
            features.update(event_code_count.copy())
            features.update(event_id_count.copy())
            features.update(title_count.copy())
            features.update(game_time_dict.copy())
            features.update(title_event_code_count.copy())
            features.update(last_accuracy_title.copy())
            features.update(assess_4020_acc_dict.copy())
            features.update(type_world_count.copy())
            
            features['installation_session_count'] = sessions_count
            features['accumulated_game_miss'] = accumulated_game_miss
            features['mean_game_round'] = mean_game_round
            features['mean_game_duration'] = mean_game_duration
            features['mean_game_level'] = mean_game_level
            features['Assessment_mean_event_count'] = Assessment_mean_event_count
            features['Game_mean_event_count'] = Game_mean_event_count
            features['Activity_mean_event_count'] = Activity_mean_event_count
            features['chest_assessment_uncorrect_sum'] = chest_assessment_uncorrect_sum
            
            variety_features = [('var_event_code', event_code_count),
                              ('var_event_id', event_id_count),
                               ('var_title', title_count),
                               ('var_title_event_code', title_event_code_count),
                                ('var_type_world', type_world_count)]
            
            for name, dict_counts in variety_features:
                arr = np.array(list(dict_counts.values()))
                features[name] = np.count_nonzero(arr)
                 
            # get installation_id for aggregated features
            features['installation_id'] = session['installation_id'].iloc[-1]
            # add title as feature, remembering that title represents the name of the game
            features['session_title'] = session['title'].iloc[0]
            # the 4 lines below add the feature of the history of the trials of this player
            # this is based on the all time attempts so far, at the moment of this assessment
            features['accumulated_correct_attempts'] = accumulated_correct_attempts
            features['accumulated_uncorrect_attempts'] = accumulated_uncorrect_attempts
            accumulated_correct_attempts += true_attempts 
            accumulated_uncorrect_attempts += false_attempts
            # the time spent in the app so far
            if durations == []:
                features['duration_mean'] = 0
                features['duration_std'] = 0
            else:
                features['duration_mean'] = np.mean(durations)
                features['duration_std'] = np.std(durations)
            durations.append((session.iloc[-1, 2] - session.iloc[0, 2] ).seconds)
            # the accurace is the all time wins divided by the all time attempts
            features['accumulated_accuracy'] = accumulated_accuracy/counter if counter > 0 else 0
            
            features['Cauldron_Filler_4025'] = Cauldron_Filler_4025/counter if counter > 0 else 0
            ####################
            Assess_4025 = session[(session.event_code == 4025) & (session.title=='Cauldron Filler (Assessment)')]   
            true_attempts_ = Assess_4025['event_data'].str.contains('true').sum()
            false_attempts_ = Assess_4025['event_data'].str.contains('false').sum()

            cau_assess_accuracy_ = true_attempts_/(true_attempts_+false_attempts_) if (true_attempts_+false_attempts_) != 0 else 0
            Cauldron_Filler_4025 += cau_assess_accuracy_
            
            chest_assessment_uncorrect_sum += len(session[session.event_id=="df4fe8b6"])
            
            Assessment_mean_event_count = (Assessment_mean_event_count + session['event_count'].iloc[-1])/2.0
            ##############################
            accuracy = true_attempts/(true_attempts+false_attempts) if (true_attempts+false_attempts) != 0 else 0
            accumulated_accuracy += accuracy
            last_accuracy_title['acc_' + session_title_text] = accuracy
            # a feature of the current accuracy categorized
            # it is a counter of how many times this player was in each accuracy group
            if accuracy == 0:
                features['accuracy_group'] = 0
            elif accuracy == 1:
                features['accuracy_group'] = 3
            elif accuracy == 0.5:
                features['accuracy_group'] = 2
            else:
                features['accuracy_group'] = 1
            features.update(accuracy_groups)
            accuracy_groups[features['accuracy_group']] += 1
            # mean of the all accuracy groups of this player
            features['accumulated_accuracy_group'] = accumulated_accuracy_group/counter if counter > 0 else 0
            accumulated_accuracy_group += features['accuracy_group']
            # how many actions the player has done so far, it is initialized as 0 and updated some lines below
            features['accumulated_actions'] = accumulated_actions
            
            # there are some conditions to allow this features to be inserted in the datasets
            # if it's a test set, all sessions belong to the final dataset
            # it it's a train, needs to be passed throught this clausule: session.query(f'event_code == {win_code[session_title]}')
            # that means, must exist an event_code 4100 or 4110
            if test_set:
                all_assessments.append(features)
            elif true_attempts+false_attempts > 0:
                all_assessments.append(features)
                
            counter += 1
        
        # end session_type=="Assessment"
        
        sessions_count += 1
        # this piece counts how many actions was made in each event_code so far
        def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = k
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            
        event_code_count = update_counters(event_code_count, "event_code")
        event_id_count = update_counters(event_id_count, "event_id")
        title_count = update_counters(title_count, 'title')
        title_event_code_count = update_counters(title_event_code_count, 'title_event_code')
        type_world_count = update_counters(type_world_count, 'type_world')
        
        assess_4020_acc_dict = get_4020_acc(session , assess_4020_acc_dict)
        game_time_dict[session_type+'_gametime'] = (game_time_dict[session_type+'_gametime'] + (session['game_time'].iloc[-1]/1000.0))/2.0
        
        # counts how many actions the player has done so far, used in the feature of the same name
        accumulated_actions += len(session)
        if last_activity != session_type:
            user_activities_count[session_type] += 1
            last_activitiy = session_type 
                        
    # if it't the test_set, only the last assessment must be predicted, the previous are scraped
    if test_set:
        return all_assessments[-1]
    # in the train_set, all assessments goes to the dataset
    return all_assessments

# %%
def preprocess(reduce_train, reduce_test):
    for df in [reduce_train, reduce_test]:
        df['installation_session_count'] = df.groupby(['installation_id'])['Clip'].transform('count')
        df['installation_duration_mean'] = df.groupby(['installation_id'])['duration_mean'].transform('mean')
        #df['installation_duration_std'] = df.groupby(['installation_id'])['duration_mean'].transform('std')
        df['installation_title_nunique'] = df.groupby(['installation_id'])['session_title'].transform('nunique')
        
        df['sum_event_code_count'] = df[[2050, 4100, 4230, 5000, 4235, 2060, 4110, 5010, 2070, 2075, 2080, 2081, 2083, 3110, 4010, 3120, 3121, 4020, 4021, 
                                        4022, 4025, 4030, 4031, 3010, 4035, 4040, 3020, 3021, 4045, 2000, 4050, 2010, 2020, 4070, 2025, 2030, 4080, 2035, 
                                        2040, 4090, 4220, 4095]].sum(axis = 1)
        
        df['installation_event_code_count_mean'] = df.groupby(['installation_id'])['sum_event_code_count'].transform('mean')
        #df['installation_event_code_count_std'] = df.groupby(['installation_id'])['sum_event_code_count'].transform('std')
        
    features = reduce_train.loc[(reduce_train.sum(axis=1) != 0), (reduce_train.sum(axis=0) != 0)].columns # delete useless columns
    features = [x for x in features if x not in ['accuracy_group', 'installation_id']] + ['acc_' + title for title in assess_titles]
   
    return reduce_train, reduce_test, features

# %%
def get_train_and_test(train, test):
    compiled_train = []
    compiled_test = []
    for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
        compiled_train += get_data(user_sample)
    for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
        test_data = get_data(user_sample, test_set = True)
        compiled_test.append(test_data)
    reduce_train = pd.DataFrame(compiled_train)
    reduce_test = pd.DataFrame(compiled_test)
    categoricals = ['session_title']
    return reduce_train, reduce_test, categoricals

# %%
# read data
train, test, train_labels, specs, sample_submission = read_data()
# get usefull dict with maping encode
# train, test, train_labels, win_code, list_of_user_activities, \
# list_of_event_code, activities_labels, assess_titles, list_of_event_id,\
# all_title_event_code = encode_title(train, test, train_labels)

train, test, train_labels, win_code, list_of_user_activities, \
list_of_event_code, activities_labels, assess_titles, list_of_event_id, \
all_title_event_code, activities_map, all_type_world \
= encode_title(train, test, train_labels)
# Out:
# Reading train.csv file....
# Training.csv file have 11341042 rows and 11 columns
# Reading test.csv file....
# Test.csv file have 1156414 rows and 11 columns
# Reading train_labels.csv file....
# Train_labels.csv file have 17690 rows and 7 columns
# Reading specs.csv file....
# Specs.csv file have 386 rows and 3 columns
# Reading sample_submission.csv file....
# Sample_submission.csv file have 1000 rows and 2 columns

# %%
class Base_Model(object):
    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True, params=None):
        self.train_df = train_df
        self.test_df = test_df
        self.features = features
        self.n_splits = n_splits
        self.categoricals = categoricals
        self.target = 'accuracy_group'
        self.cv = self.get_cv()
        self.verbose = verbose
        self.params = self.get_params(params)
        self.y_pred, self.oof_pred, self.score, self.model = self.fit()
        
    def train_model(self, train_set, val_set):
        raise NotImplementedError
        
    def get_cv(self):
        cv = StratifiedKFold(n_splits=self.n_splits, shuffle=True, random_state=42)
#         cv = GroupKFold(n_splits=self.n_splits)
        return cv.split(self.train_df, self.train_df[self.target])
    
    def get_params(self, params):
        raise NotImplementedError
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        raise NotImplementedError
        
    def convert_x(self, x):
        return x
        
    def fit(self):
        oof_pred = np.zeros((len(reduce_train), ))
        y_pred = np.zeros((len(reduce_test), ))
        for fold, (train_idx, val_idx) in enumerate(self.cv):
            # 相当于降维
            x_train, x_val = self.train_df[self.features].iloc[train_idx], self.train_df[self.features].iloc[val_idx]   
            y_train, y_val = self.train_df[self.target][train_idx], self.train_df[self.target][val_idx]
            # 针对不同模型处理数据
            train_set, val_set = self.convert_dataset(x_train, y_train, x_val, y_val)
            # 针对不同模型训练数据
            model = self.train_model(train_set, val_set) 
            # 得到验证数据的预测值
            conv_x_val = self.convert_x(x_val)
            oof_pred[val_idx] = model.predict(conv_x_val).reshape(oof_pred[val_idx].shape)
            # 得到测试数据的预测值
            x_test = self.convert_x(self.test_df[self.features])
            y_pred += model.predict(x_test).reshape(y_pred.shape) / self.n_splits
            print('Partial score of fold {} is: {}'.format(fold, eval_qwk_lgb_regr(y_val, oof_pred[val_idx])[1]))
        _, loss_score, _ = eval_qwk_lgb_regr(self.train_df[self.target], oof_pred)
        if self.verbose:
            print('Our oof cohen kappa score is: ', loss_score)
        return y_pred, oof_pred, loss_score, model

# %%
class Lgb_Model(Base_Model):
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return lgb.train(self.params, train_set, valid_sets=[train_set, val_set], verbose_eval=verbosity)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = lgb.Dataset(x_train, y_train, categorical_feature=self.categoricals)
        val_set = lgb.Dataset(x_val, y_val, categorical_feature=self.categoricals)
        return train_set, val_set
        
    def get_params(self, params=None):
        if params is None :
            default_params = {
                'n_estimators':2000,
                'boosting_type': 'gbdt',
                'objective': 'regression',
                'metric': 'rmse',
                'n_jobs': -1,
                'eval_metric': 'cappa',
                'subsample': 0.75,
                'subsample_freq': 1,
                'learning_rate': 0.01,
                'feature_fraction': 0.9,
                'max_depth': 15,
                'lambda_l1': 1,  
                'lambda_l2': 1,
                'early_stopping_rounds': 100}
        else:
            default_params = {
                "bagging_seed": 11,
                'verbose': 100,
                "verbosity": -1,
                'seed': 42,
                'n_estimators':2000,
                'subsample': 0.75,
                'subsample_freq': 1,
                'n_jobs': -1,
                'boosting_type': 'gbdt',
                'objective': 'regression',
                'metric': 'rmse',
                'early_stopping_rounds': 100,
                'eval_metric': 'cappa',
                'learning_rate': params['learning_rate'],
#                 'feature_fraction': params['feature_fraction'],
                'colsample_bytree': params['colsample_bytree'], 
                'bagging_fraction': params['bagging_fraction'],
                'bagging_freq': int(params['bagging_freq']),
                'max_depth': int(params['max_depth']),
                'lambda_l1': params['lambda_l1'],  
                'lambda_l2': params['lambda_l2']}
        return default_params

# %%
class Xgb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return xgb.train(self.params, 
                         train_set, 
                         num_boost_round=5000, 
                         evals=[(train_set, 'train'), 
                                (val_set, 'val')], 
                         verbose_eval=verbosity,
                         early_stopping_rounds=100)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = xgb.DMatrix(x_train, y_train)
        val_set = xgb.DMatrix(x_val, y_val)
        return train_set, val_set
    
    def convert_x(self, x):
        return xgb.DMatrix(x)
        
    def get_params(self, params=None):
        if params is None :
            default_params = {
                      'colsample_bytree': 0.8,                 
                      'learning_rate': 0.01,
                      'max_depth': 10,
                      'subsample': 1,
                      'objective':'reg:squarederror',
                      #'eval_metric':'rmse',
                      'min_child_weight':3,
                      'gamma':0.25,
                      'n_estimators':2000}
        else:
            default_params = {
                  'colsample_bytree': params['colsample_bytree'],                 
                  'learning_rate': 0.01,
                  'max_depth': int(params['max_depth']),
                  'subsample': params['subsample'],
                  'objective':'reg:squarederror',
                  #'eval_metric':'rmse',
                  'min_child_weight':params['min_child_weight'],
                  'gamma': params['gamma'],
                  'n_estimators':2000,
                  'max_delta_step': params['max_delta_step']}
        return default_params

# %%
class Catb_Model(Base_Model):
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        clf = CatBoostRegressor(**self.params)
        clf.fit(train_set['X'], 
                train_set['y'], 
                eval_set=(val_set['X'], val_set['y']),
                verbose=verbosity, 
                cat_features=self.categoricals)
        return clf
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = {'X': x_train, 'y': y_train}
        val_set = {'X': x_val, 'y': y_val}
        return train_set, val_set
        
    def get_params(self, params=None):
        if params is None :
            default_params = {
                    'loss_function': 'RMSE',
                    'task_type': "CPU",
                    'iterations': 2000,
                    'od_type': "Iter",
                    'depth': 10,
                    'colsample_bylevel': 0.5, 
                    'early_stopping_rounds': 300,
                    'l2_leaf_reg': 18,
                    'random_seed': 42,
                    'use_best_model': True}
        else:
            default_params = {
                    'loss_function': 'RMSE',
                    'task_type': "CPU",
                    'iterations': 2000,
                    'od_type': "Iter",
                    'depth': int(params['depth']),
                    'early_stopping_rounds': 300,
                    'colsample_bylevel': params['min_child_weight'], 
                    'l2_leaf_reg': params['l2_leaf_reg'],
                    'learning_rate': parmas['learning_rate'],
                    'random_seed': 42,
                    'use_best_model': True}
        return default_params

# %%
# feature engineering
reduce_train, reduce_test, categoricals = get_train_and_test(train, test)
reduce_train.to_csv(base_dir + 'reduce_train.csv')
reduce_test.to_csv(base_dir + 'reduce_test.csv')
# Out:
# This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=17000.0), HTML(value='')))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-d5c8a19a544d> in <module>
#       1 # feature engineering
# ----> 2 reduce_train, reduce_test, categoricals = get_train_and_test(train, test)
#       3 reduce_train.to_csv(base_dir + 'reduce_train.csv')
#       4 reduce_test.to_csv(base_dir + 'reduce_test.csv')
#
# <ipython-input-55-2d9970e15759> in get_train_and_test(train, test)
#       3     compiled_test = []
#       4     for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
# ----> 5         compiled_train += get_data(user_sample)
#       6     for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
#       7         test_data = get_data(user_sample, test_set = True)
#
# <ipython-input-53-660ccb8f7988> in get_data(user_sample, test_set)
#      17     accumulated_positive_events = 0
#      18     accumulated_negative_events = 0
# ---> 19     accumulated_positive_title = {'accumulated_positive_'+t: 0 for t in activity_game_titles}
#      20     accumulated_negative_title = {'accumulated_negative_'+t: 0 for t in activity_game_titles}
#      21     accumulated_positive_title_ratio = {'accumulated_positive_ratio_'+t: 0 for t in activity_game_titles}
#
# NameError: name 'activity_game_titles' is not defined

# %%
reduce_train.shape
# Out:
# (17690, 932)

# %%
features = reduce_train.loc[(reduce_train.sum(axis=1) != 0), (reduce_train.sum(axis=0) != 0)].columns # delete useless columns
features = [x for x in features if x not in ['accuracy_group', 'installation_id']]

# %%
counter = 0
to_remove = []
for feat_a in features:
    for feat_b in features:
        if feat_a != feat_b and feat_a not in to_remove and feat_b not in to_remove:
            c = np.corrcoef(reduce_train[feat_a], reduce_train[feat_b])[0][1]
            if c > 0.995:
                counter += 1
                to_remove.append(feat_b)
                print('{}: FEAT_A: {} FEAT_B: {} - Correlation: {}'.format(counter, feat_a, feat_b, c))
# Out:
# 1: FEAT_A: Clip FEAT_B: 27253bdc - Correlation: 0.9999999999999999
# 2: FEAT_A: 2050 FEAT_B: 2040 - Correlation: 0.9965259434878118
# 3: FEAT_A: 2050 FEAT_B: 73757a5e - Correlation: 0.9998050146713992
# 4: FEAT_A: 2050 FEAT_B: 37c53127 - Correlation: 1.0
# 5: FEAT_A: 2050 FEAT_B: 08fd73f3 - Correlation: 0.9966123918733654
# 6: FEAT_A: 2050 FEAT_B: dcaede90 - Correlation: 0.9965259434878118
# 7: FEAT_A: 2050 FEAT_B: 2b9272f4 - Correlation: 0.9999839030068793
# 8: FEAT_A: 2050 FEAT_B: 26fd2d99 - Correlation: 0.9965084543995759
# 9: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2030 - Correlation: 0.9966123918733654
# 10: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_3121 - Correlation: 0.9999839030068793
# 11: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2050 - Correlation: 1.0
# 12: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_3021 - Correlation: 0.9998050146713992
# 13: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2040 - Correlation: 0.9965259434878118
# 14: FEAT_A: 2050 FEAT_B: Scrub-A-Dub_2020 - Correlation: 0.9965084543995759
# 15: FEAT_A: 4230 FEAT_B: 4235 - Correlation: 0.9999995197498746
# 16: FEAT_A: 4230 FEAT_B: 85de926c - Correlation: 0.9999995197498746
# 17: FEAT_A: 4230 FEAT_B: ad148f58 - Correlation: 0.9999999999999998
# 18: FEAT_A: 4230 FEAT_B: Bubble Bath_4230 - Correlation: 0.9999999999999998
# 19: FEAT_A: 4230 FEAT_B: Bubble Bath_4235 - Correlation: 0.9999995197498746
# 20: FEAT_A: 5000 FEAT_B: 5010 - Correlation: 0.9991849213605333
# 21: FEAT_A: 5000 FEAT_B: a6d66e51 - Correlation: 1.0
# 22: FEAT_A: 5000 FEAT_B: 71e712d8 - Correlation: 0.9991849213605333
# 23: FEAT_A: 5000 FEAT_B: Watering Hole (Activity)_5000 - Correlation: 1.0
# 24: FEAT_A: 5000 FEAT_B: Watering Hole (Activity)_5010 - Correlation: 0.9991849213605333
# 25: FEAT_A: 3110 FEAT_B: 3010 - Correlation: 0.9999293402893735
# 26: FEAT_A: 3120 FEAT_B: 3020 - Correlation: 0.9998761417908972
# 27: FEAT_A: 3121 FEAT_B: 3021 - Correlation: 0.9999098200487934
# 28: FEAT_A: 4031 FEAT_B: 1996c610 - Correlation: 1.0
# 29: FEAT_A: 4031 FEAT_B: Dino Drink_4031 - Correlation: 1.0
# 30: FEAT_A: 2000 FEAT_B: installation_session_count - Correlation: 1.0
# 31: FEAT_A: 4050 FEAT_B: a1192f43 - Correlation: 0.9999999999999999
# 32: FEAT_A: 4050 FEAT_B: Crystals Rule_4050 - Correlation: 0.9999999999999999
# 33: FEAT_A: 2020 FEAT_B: 2030 - Correlation: 0.9959933262816534
# 34: FEAT_A: 4220 FEAT_B: 1340b8d7 - Correlation: 1.0
# 35: FEAT_A: 4220 FEAT_B: Bubble Bath_4220 - Correlation: 1.0
# 36: FEAT_A: 7ec0c298 FEAT_B: Chow Time_3010 - Correlation: 0.9999999999999999
# 37: FEAT_A: 74e5f8a7 FEAT_B: Dino Drink_4020 - Correlation: 1.0
# 38: FEAT_A: d2659ab4 FEAT_B: Air Show_2075 - Correlation: 1.0
# 39: FEAT_A: 363c86c9 FEAT_B: Bug Measurer (Activity)_4035 - Correlation: 1.0
# 40: FEAT_A: b012cd7f FEAT_B: e5c9df6f - Correlation: 0.9990885395773584
# 41: FEAT_A: b012cd7f FEAT_B: 3afde5dd - Correlation: 0.9999689260314981
# 42: FEAT_A: b012cd7f FEAT_B: Leaf Leader_3021 - Correlation: 0.9999689260314981
# 43: FEAT_A: b012cd7f FEAT_B: Leaf Leader_3121 - Correlation: 0.9990885395773584
# 44: FEAT_A: b012cd7f FEAT_B: Leaf Leader_2030 - Correlation: 1.0
# 45: FEAT_A: c0415e5c FEAT_B: Dino Dive_4020 - Correlation: 1.0
# 46: FEAT_A: 1cf54632 FEAT_B: Bubble Bath_2000 - Correlation: 0.9999999999999999
# 47: FEAT_A: a2df0760 FEAT_B: Happy Camel_4035 - Correlation: 0.9999999999999999
# 48: FEAT_A: ab4ec3a4 FEAT_B: Dino Drink_4080 - Correlation: 1.0
# 49: FEAT_A: 5b49460a FEAT_B: 155f62a4 - Correlation: 0.9999999999999999
# 50: FEAT_A: 5b49460a FEAT_B: Chest Sorter (Assessment)_2020 - Correlation: 0.9999999999999999
# 51: FEAT_A: 5b49460a FEAT_B: Chest Sorter (Assessment)_2000 - Correlation: 0.9999999999999999
# 52: FEAT_A: 9e4c8c7b FEAT_B: 363d3849 - Correlation: 0.9992130941883633
# 53: FEAT_A: 9e4c8c7b FEAT_B: All Star Sorting_3110 - Correlation: 0.9999999999999998
# 54: FEAT_A: 9e4c8c7b FEAT_B: All Star Sorting_3010 - Correlation: 0.9992130941883633
# 55: FEAT_A: 06372577 FEAT_B: Air Show_2060 - Correlation: 1.0
# 56: FEAT_A: d2e9262e FEAT_B: 2fb91ec1 - Correlation: 0.9991434495208743
# 57: FEAT_A: d2e9262e FEAT_B: Watering Hole (Activity)_4025 - Correlation: 0.9991434495208743
# 58: FEAT_A: d2e9262e FEAT_B: Watering Hole (Activity)_4020 - Correlation: 0.9999999999999998
# 59: FEAT_A: 119b5b02 FEAT_B: Dino Dive_4080 - Correlation: 1.0
# 60: FEAT_A: cf82af56 FEAT_B: Scrub-A-Dub_4070 - Correlation: 1.0
# 61: FEAT_A: a8a78786 FEAT_B: c7fe2a55 - Correlation: 0.9981452039350778
# 62: FEAT_A: a8a78786 FEAT_B: 36fa3ebe - Correlation: 0.9979559120623818
# 63: FEAT_A: a8a78786 FEAT_B: Happy Camel_3121 - Correlation: 0.9999999999999999
# 64: FEAT_A: a8a78786 FEAT_B: Happy Camel_2030 - Correlation: 0.9979559120623818
# 65: FEAT_A: a8a78786 FEAT_B: Happy Camel_3021 - Correlation: 0.9981452039350778
# 66: FEAT_A: 25fa8af4 FEAT_B: Mushroom Sorter (Assessment)_4100 - Correlation: 1.0
# 67: FEAT_A: 37db1c2f FEAT_B: Happy Camel_4045 - Correlation: 1.0
# 68: FEAT_A: 6f8106d9 FEAT_B: Dino Drink_4090 - Correlation: 1.0
# 69: FEAT_A: 262136f4 FEAT_B: Leaf Leader_4020 - Correlation: 1.0
# 70: FEAT_A: 3b2048ee FEAT_B: Leaf Leader_4095 - Correlation: 1.0
# 71: FEAT_A: 3ddc79c3 FEAT_B: e720d930 - Correlation: 0.9998920962508026
# 72: FEAT_A: 3ddc79c3 FEAT_B: 7cf1bc53 - Correlation: 0.99823323877902
# 73: FEAT_A: 3ddc79c3 FEAT_B: 3323d7e9 - Correlation: 0.9998606654761331
# 74: FEAT_A: 3ddc79c3 FEAT_B: Crystals Rule_2030 - Correlation: 0.9998606654761331
# 75: FEAT_A: 3ddc79c3 FEAT_B: Crystals Rule_3121 - Correlation: 0.9998920962508026
# 76: FEAT_A: 3ddc79c3 FEAT_B: Crystals Rule_3021 - Correlation: 0.9999999999999998
# 77: FEAT_A: 3ddc79c3 FEAT_B: Crystals Rule_2020 - Correlation: 0.99823323877902
# 78: FEAT_A: 02a42007 FEAT_B: Fireworks (Activity)_4030 - Correlation: 1.0
# 79: FEAT_A: c7128948 FEAT_B: Mushroom Sorter (Assessment)_4040 - Correlation: 1.0
# 80: FEAT_A: 2a512369 FEAT_B: 33505eae - Correlation: 0.9994585292841954
# 81: FEAT_A: 2a512369 FEAT_B: Leaf Leader_3010 - Correlation: 0.9994585292841954
# 82: FEAT_A: 2a512369 FEAT_B: Leaf Leader_3110 - Correlation: 1.0
# 83: FEAT_A: 070a5291 FEAT_B: Bird Measurer (Assessment)_4100 - Correlation: 1.0
# 84: FEAT_A: 28f975ea FEAT_B: Air Show_4020 - Correlation: 1.0
# 85: FEAT_A: 56cd3b43 FEAT_B: bbfe0445 - Correlation: 0.9996926215355526
# 86: FEAT_A: 56cd3b43 FEAT_B: Flower Waterer (Activity)_3010 - Correlation: 1.0
# 87: FEAT_A: 56cd3b43 FEAT_B: Flower Waterer (Activity)_3110 - Correlation: 0.9996926215355526
# 88: FEAT_A: 7da34a02 FEAT_B: Mushroom Sorter (Assessment)_4070 - Correlation: 0.9999999999999998
# 89: FEAT_A: 3dcdda7f FEAT_B: 3ccd3f02 - Correlation: 0.9977337946782758
# 90: FEAT_A: 3dcdda7f FEAT_B: Chest Sorter (Assessment)_3010 - Correlation: 1.0
# 91: FEAT_A: 3dcdda7f FEAT_B: Chest Sorter (Assessment)_3110 - Correlation: 0.9977337946782758
# 92: FEAT_A: fcfdffb6 FEAT_B: Flower Waterer (Activity)_4022 - Correlation: 1.0
# 93: FEAT_A: e7e44842 FEAT_B: Watering Hole (Activity)_4090 - Correlation: 0.9999999999999999
# 94: FEAT_A: 51102b85 FEAT_B: Bird Measurer (Assessment)_4030 - Correlation: 1.0
# 95: FEAT_A: 69fdac0a FEAT_B: 8d7e386c - Correlation: 0.9996590210382708
# 96: FEAT_A: 69fdac0a FEAT_B: Happy Camel_3110 - Correlation: 0.9999999999999999
# 97: FEAT_A: 69fdac0a FEAT_B: Happy Camel_3010 - Correlation: 0.9996590210382708
# 98: FEAT_A: bc8f2793 FEAT_B: Pan Balance_4035 - Correlation: 0.9999999999999999
# 99: FEAT_A: b74258a0 FEAT_B: b2e5b0f1 - Correlation: 0.999849464604504
# 100: FEAT_A: b74258a0 FEAT_B: ecaab346 - Correlation: 1.0
# 101: FEAT_A: b74258a0 FEAT_B: Cart Balancer (Assessment)_2030 - Correlation: 1.0
# 102: FEAT_A: b74258a0 FEAT_B: Cart Balancer (Assessment)_3121 - Correlation: 1.0
# 103: FEAT_A: b74258a0 FEAT_B: Cart Balancer (Assessment)_2010 - Correlation: 0.999849464604504
# 104: FEAT_A: 0413e89d FEAT_B: 15eb4a7d - Correlation: 0.9997266832893074
# 105: FEAT_A: 0413e89d FEAT_B: Bubble Bath_3010 - Correlation: 1.0
# 106: FEAT_A: 0413e89d FEAT_B: Bubble Bath_3110 - Correlation: 0.9997266832893074
# 107: FEAT_A: c1cac9a2 FEAT_B: Scrub-A-Dub_2081 - Correlation: 0.9999999999999998
# 108: FEAT_A: a5be6304 FEAT_B: 6c930e6e - Correlation: 0.996276061682167
# 109: FEAT_A: a5be6304 FEAT_B: Mushroom Sorter (Assessment)_2010 - Correlation: 1.0
# 110: FEAT_A: a5be6304 FEAT_B: Mushroom Sorter (Assessment)_2030 - Correlation: 0.996276061682167
# 111: FEAT_A: f6947f54 FEAT_B: Bird Measurer (Assessment)_2030 - Correlation: 1.0
# 112: FEAT_A: 2b058fe3 FEAT_B: Cauldron Filler (Assessment)_2010 - Correlation: 1.0
# 113: FEAT_A: f56e0afc FEAT_B: Bird Measurer (Assessment)_2000 - Correlation: 1.0
# 114: FEAT_A: 63f13dd7 FEAT_B: Chow Time_2020 - Correlation: 1.0
# 115: FEAT_A: 2dc29e21 FEAT_B: All Star Sorting_4020 - Correlation: 1.0
# 116: FEAT_A: f5b8c21a FEAT_B: 9b4001e4 - Correlation: 0.9976837802056778
# 117: FEAT_A: f5b8c21a FEAT_B: 58a0de5c - Correlation: 0.9977888184537717
# 118: FEAT_A: f5b8c21a FEAT_B: Air Show_3121 - Correlation: 0.9977888184537717
# 119: FEAT_A: f5b8c21a FEAT_B: Air Show_2030 - Correlation: 1.0
# 120: FEAT_A: f5b8c21a FEAT_B: Air Show_3021 - Correlation: 0.9976837802056778
# 121: FEAT_A: 5be391b5 FEAT_B: Dino Drink_4010 - Correlation: 1.0
# 122: FEAT_A: 28520915 FEAT_B: d3268efa - Correlation: 0.9989055023166136
# 123: FEAT_A: 28520915 FEAT_B: b5053438 - Correlation: 0.999090516610188
# 124: FEAT_A: 28520915 FEAT_B: Cauldron Filler (Assessment)_3121 - Correlation: 0.999090516610188
# 125: FEAT_A: 28520915 FEAT_B: Cauldron Filler (Assessment)_2030 - Correlation: 1.0
# 126: FEAT_A: 28520915 FEAT_B: Cauldron Filler (Assessment)_3021 - Correlation: 0.9989055023166136
# 127: FEAT_A: 47026d5f FEAT_B: cb6010f8 - Correlation: 0.9996901555713447
# 128: FEAT_A: 47026d5f FEAT_B: 56817e2b - Correlation: 0.9993683693704368
# 129: FEAT_A: 47026d5f FEAT_B: Chow Time_3021 - Correlation: 1.0
# 130: FEAT_A: 47026d5f FEAT_B: Chow Time_2030 - Correlation: 0.9993683693704368
# 131: FEAT_A: 47026d5f FEAT_B: Chow Time_3121 - Correlation: 0.9996901555713447
# 132: FEAT_A: 9ce586dd FEAT_B: Chest Sorter (Assessment)_4035 - Correlation: 1.0
# 133: FEAT_A: abc5811c FEAT_B: Happy Camel_4010 - Correlation: 1.0
# 134: FEAT_A: c2baf0bd FEAT_B: Happy Camel_2020 - Correlation: 1.0
# 135: FEAT_A: a7640a16 FEAT_B: Happy Camel_4070 - Correlation: 1.0
# 136: FEAT_A: b7530680 FEAT_B: e9c52111 - Correlation: 0.998817689964623
# 137: FEAT_A: b7530680 FEAT_B: Bottle Filler (Activity)_2020 - Correlation: 1.0
# 138: FEAT_A: b7530680 FEAT_B: Bottle Filler (Activity)_2030 - Correlation: 0.998817689964623
# 139: FEAT_A: fd20ea40 FEAT_B: Leaf Leader_4010 - Correlation: 0.9999999999999998
# 140: FEAT_A: 2230fab4 FEAT_B: 0330ab6a - Correlation: 0.9998673365188064
# 141: FEAT_A: 2230fab4 FEAT_B: Chow Time_3020 - Correlation: 0.9998673365188064
# 142: FEAT_A: 2230fab4 FEAT_B: Chow Time_3120 - Correlation: 0.9999999999999999
# 143: FEAT_A: 587b5989 FEAT_B: All Star Sorting_4070 - Correlation: 1.0
# 144: FEAT_A: 0086365d FEAT_B: Pan Balance_4010 - Correlation: 0.9999999999999999
# 145: FEAT_A: 90ea0bac FEAT_B: 5859dfb6 - Correlation: 0.9981052472610569
# 146: FEAT_A: 90ea0bac FEAT_B: Bubble Bath_3120 - Correlation: 0.9981052472610569
# 147: FEAT_A: 90ea0bac FEAT_B: Bubble Bath_3020 - Correlation: 1.0
# 148: FEAT_A: 8ac7cce4 FEAT_B: Leaf Leader_2000 - Correlation: 1.0
# 149: FEAT_A: ec138c1c FEAT_B: Bird Measurer (Assessment)_2020 - Correlation: 0.9999999999999999
# 150: FEAT_A: 7dfe6d8a FEAT_B: Leaf Leader_4070 - Correlation: 0.9999999999999998
# 151: FEAT_A: 47f43a44 FEAT_B: Flower Waterer (Activity)_4090 - Correlation: 1.0
# 152: FEAT_A: 5e109ec3 FEAT_B: Cart Balancer (Assessment)_4030 - Correlation: 1.0
# 153: FEAT_A: 16dffff1 FEAT_B: 77ead60d - Correlation: 0.9984674845132689
# 154: FEAT_A: 16dffff1 FEAT_B: 4d911100 - Correlation: 0.9986046680098601
# 155: FEAT_A: 16dffff1 FEAT_B: Dino Drink_3121 - Correlation: 0.9986046680098601
# 156: FEAT_A: 16dffff1 FEAT_B: Dino Drink_2030 - Correlation: 0.9999999999999999
# 157: FEAT_A: 16dffff1 FEAT_B: Dino Drink_3021 - Correlation: 0.9984674845132689
# 158: FEAT_A: f71c4741 FEAT_B: f7e47413 - Correlation: 0.9999426890770878
# 159: FEAT_A: f71c4741 FEAT_B: Scrub-A-Dub_3110 - Correlation: 0.9999426890770878
# 160: FEAT_A: f71c4741 FEAT_B: Scrub-A-Dub_3010 - Correlation: 1.0
# 161: FEAT_A: 2dcad279 FEAT_B: 923afab1 - Correlation: 0.9998567985670083
# 162: FEAT_A: 2dcad279 FEAT_B: Cauldron Filler (Assessment)_3110 - Correlation: 0.9999999999999999
# 163: FEAT_A: 2dcad279 FEAT_B: Cauldron Filler (Assessment)_3010 - Correlation: 0.9998567985670083
# 164: FEAT_A: 6f445b57 FEAT_B: Chow Time_4080 - Correlation: 1.0
# 165: FEAT_A: 90d848e0 FEAT_B: Cauldron Filler (Assessment)_2000 - Correlation: 1.0
# 166: FEAT_A: e3ff61fb FEAT_B: 709b1251 - Correlation: 0.9995444786291265
# 167: FEAT_A: e3ff61fb FEAT_B: Dino Dive_3021 - Correlation: 1.0
# 168: FEAT_A: e3ff61fb FEAT_B: Dino Dive_3121 - Correlation: 0.9995444786291265
# 169: FEAT_A: 71fe8f75 FEAT_B: 0a08139c - Correlation: 0.9999850342981554
# 170: FEAT_A: 71fe8f75 FEAT_B: Bug Measurer (Activity)_3110 - Correlation: 1.0
# 171: FEAT_A: 71fe8f75 FEAT_B: Bug Measurer (Activity)_3010 - Correlation: 0.9999850342981554
# 172: FEAT_A: 4c2ec19f FEAT_B: Egg Dropper (Activity)_4025 - Correlation: 1.0
# 173: FEAT_A: f93fc684 FEAT_B: Chow Time_4010 - Correlation: 0.9999999999999999
# 174: FEAT_A: 31973d56 FEAT_B: 5de79a6a - Correlation: 0.9973945339840646
# 175: FEAT_A: 31973d56 FEAT_B: Cart Balancer (Assessment)_3120 - Correlation: 1.0
# 176: FEAT_A: 31973d56 FEAT_B: Cart Balancer (Assessment)_3020 - Correlation: 0.9973945339840646
# 177: FEAT_A: 51311d7a FEAT_B: Dino Drink_2000 - Correlation: 1.0
# 178: FEAT_A: 84b0e0c8 FEAT_B: ea321fb1 - Correlation: 0.9993007600205109
# 179: FEAT_A: 84b0e0c8 FEAT_B: Chicken Balancer (Activity)_3010 - Correlation: 0.9993007600205109
# 180: FEAT_A: 84b0e0c8 FEAT_B: Chicken Balancer (Activity)_3110 - Correlation: 1.0
# 181: FEAT_A: ad2fc29c FEAT_B: 17113b36 - Correlation: 0.9988424704659317
# 182: FEAT_A: ad2fc29c FEAT_B: e37a2b78 - Correlation: 0.9992191329664104
# 183: FEAT_A: ad2fc29c FEAT_B: Bird Measurer (Assessment)_3120 - Correlation: 0.9992191329664104
# 184: FEAT_A: ad2fc29c FEAT_B: Bird Measurer (Assessment)_3020 - Correlation: 1.0
# 185: FEAT_A: ad2fc29c FEAT_B: Bird Measurer (Assessment)_4110 - Correlation: 0.9988424704659317
# 186: FEAT_A: d185d3ea FEAT_B: Chow Time_4035 - Correlation: 1.0
# 187: FEAT_A: 4a09ace1 FEAT_B: Scrub-A-Dub_2083 - Correlation: 1.0
# 188: FEAT_A: f806dc10 FEAT_B: Dino Drink_2020 - Correlation: 1.0
# 189: FEAT_A: 2c4e6db0 FEAT_B: All Star Sorting_2020 - Correlation: 1.0
# 190: FEAT_A: 3a4be871 FEAT_B: Flower Waterer (Activity)_4080 - Correlation: 1.0
# 191: FEAT_A: a8876db3 FEAT_B: Cart Balancer (Assessment)_3021 - Correlation: 1.0
# 192: FEAT_A: 3ee399c3 FEAT_B: Cauldron Filler (Assessment)_4070 - Correlation: 1.0
# 193: FEAT_A: 8af75982 FEAT_B: Happy Camel_4020 - Correlation: 1.0
# 194: FEAT_A: cfbd47c8 FEAT_B: Chow Time_4030 - Correlation: 1.0
# 195: FEAT_A: 15ba1109 FEAT_B: Air Show_2000 - Correlation: 1.0
# 196: FEAT_A: 2ec694de FEAT_B: Bug Measurer (Activity)_4080 - Correlation: 0.9999999999999998
# 197: FEAT_A: 26a5a3dd FEAT_B: All Star Sorting_4080 - Correlation: 1.0
# 198: FEAT_A: 16667cc5 FEAT_B: Chicken Balancer (Activity)_4080 - Correlation: 0.9999999999999999
# 199: FEAT_A: 9de5e594 FEAT_B: 28a4eb9a - Correlation: 0.9995923561196808
# 200: FEAT_A: 9de5e594 FEAT_B: Dino Dive_3020 - Correlation: 1.0
# 201: FEAT_A: 9de5e594 FEAT_B: Dino Dive_3120 - Correlation: 0.9995923561196808
# 202: FEAT_A: 250513af FEAT_B: 1c178d24 - Correlation: 0.9999803429610506
# 203: FEAT_A: 250513af FEAT_B: cf7638f3 - Correlation: 0.999630364081927
# 204: FEAT_A: 250513af FEAT_B: a592d54e - Correlation: 0.9973020736885158
# 205: FEAT_A: 250513af FEAT_B: Pan Balance_2020 - Correlation: 0.9973020736885158
# 206: FEAT_A: 250513af FEAT_B: Pan Balance_3121 - Correlation: 0.999630364081927
# 207: FEAT_A: 250513af FEAT_B: Pan Balance_2030 - Correlation: 0.9999803429610506
# 208: FEAT_A: 250513af FEAT_B: Pan Balance_3021 - Correlation: 1.0
# 209: FEAT_A: 832735e1 FEAT_B: ab3136ba - Correlation: 0.9998637945770242
# 210: FEAT_A: 832735e1 FEAT_B: Dino Dive_3010 - Correlation: 1.0
# 211: FEAT_A: 832735e1 FEAT_B: Dino Dive_3110 - Correlation: 0.9998637945770242
# 212: FEAT_A: 9b23e8ee FEAT_B: 736f9581 - Correlation: 0.9999999999999999
# 213: FEAT_A: 9b23e8ee FEAT_B: Egg Dropper (Activity)_2000 - Correlation: 0.9999999999999999
# 214: FEAT_A: 9b23e8ee FEAT_B: Egg Dropper (Activity)_2020 - Correlation: 0.9999999999999999
# 215: FEAT_A: 022b4259 FEAT_B: Bug Measurer (Activity)_4025 - Correlation: 0.9999999999999998
# 216: FEAT_A: 5348fd84 FEAT_B: Cauldron Filler (Assessment)_4040 - Correlation: 1.0
# 217: FEAT_A: 5290eab1 FEAT_B: 04df9b66 - Correlation: 0.9998190477466209
# 218: FEAT_A: 5290eab1 FEAT_B: Cauldron Filler (Assessment)_3120 - Correlation: 1.0
# 219: FEAT_A: 5290eab1 FEAT_B: Cauldron Filler (Assessment)_3020 - Correlation: 0.9998190477466209
# 220: FEAT_A: 3dfd4aa4 FEAT_B: 83c6c409 - Correlation: 0.9999970893851743
# 221: FEAT_A: 3dfd4aa4 FEAT_B: 28ed704e - Correlation: 0.9996618525211791
# 222: FEAT_A: 3dfd4aa4 FEAT_B: 9d29771f - Correlation: 0.9963727918475914
# 223: FEAT_A: 3dfd4aa4 FEAT_B: c74f40cd - Correlation: 0.9963968989064971
# 224: FEAT_A: 3dfd4aa4 FEAT_B: Mushroom Sorter (Assessment)_2020 - Correlation: 1.0
# 225: FEAT_A: 3dfd4aa4 FEAT_B: Mushroom Sorter (Assessment)_2035 - Correlation: 0.9999970893851743
# 226: FEAT_A: 3dfd4aa4 FEAT_B: Mushroom Sorter (Assessment)_3121 - Correlation: 0.9963968989064971
# 227: FEAT_A: 3dfd4aa4 FEAT_B: Mushroom Sorter (Assessment)_4025 - Correlation: 0.9996618525211791
# 228: FEAT_A: 3dfd4aa4 FEAT_B: Mushroom Sorter (Assessment)_3021 - Correlation: 0.9963727918475914
# 229: FEAT_A: 65abac75 FEAT_B: Air Show_4010 - Correlation: 1.0
# 230: FEAT_A: 3d8c61b0 FEAT_B: Happy Camel_4030 - Correlation: 0.9999999999999999
# 231: FEAT_A: 48349b14 FEAT_B: Crystals Rule_2000 - Correlation: 1.0
# 232: FEAT_A: b80e5e84 FEAT_B: 7ab78247 - Correlation: 0.9998336590281085
# 233: FEAT_A: b80e5e84 FEAT_B: Egg Dropper (Activity)_3010 - Correlation: 0.9998336590281085
# 234: FEAT_A: b80e5e84 FEAT_B: Egg Dropper (Activity)_3110 - Correlation: 1.0
# 235: FEAT_A: 3babcb9b FEAT_B: 5154fc30 - Correlation: 0.999986924640935
# 236: FEAT_A: 3babcb9b FEAT_B: 86c924c4 - Correlation: 0.9988970478897697
# 237: FEAT_A: 3babcb9b FEAT_B: Crystals Rule_3110 - Correlation: 1.0
# 238: FEAT_A: 3babcb9b FEAT_B: Crystals Rule_3010 - Correlation: 0.999986924640935
# 239: FEAT_A: 3babcb9b FEAT_B: Crystals Rule_4020 - Correlation: 0.9988970478897697
# 240: FEAT_A: c6971acf FEAT_B: Dino Drink_2060 - Correlation: 0.9999999999999999
# 241: FEAT_A: 3bb91dda FEAT_B: d06f75b5 - Correlation: 0.9970877409320819
# 242: FEAT_A: 3bb91dda FEAT_B: c54cf6c5 - Correlation: 0.9999701603895903
# 243: FEAT_A: 3bb91dda FEAT_B: 8f094001 - Correlation: 0.99601669329561
# 244: FEAT_A: 3bb91dda FEAT_B: 895865f3 - Correlation: 0.9962789226264855
# 245: FEAT_A: 3bb91dda FEAT_B: Bubble Bath_2035 - Correlation: 0.9970877409320819
# 246: FEAT_A: 3bb91dda FEAT_B: Bubble Bath_2030 - Correlation: 0.9962789226264855
# 247: FEAT_A: 3bb91dda FEAT_B: Bubble Bath_4045 - Correlation: 0.99601669329561
# 248: FEAT_A: 3bb91dda FEAT_B: Bubble Bath_2025 - Correlation: 0.9999701603895903
# 249: FEAT_A: 3bb91dda FEAT_B: Bubble Bath_4020 - Correlation: 0.9999999999999998
# 250: FEAT_A: 0db6d71d FEAT_B: Chest Sorter (Assessment)_4020 - Correlation: 1.0
# 251: FEAT_A: 7423acbc FEAT_B: e04fb33d - Correlation: 0.999628997408126
# 252: FEAT_A: 7423acbc FEAT_B: Air Show_3120 - Correlation: 0.999628997408126
# 253: FEAT_A: 7423acbc FEAT_B: Air Show_3020 - Correlation: 1.0
# 254: FEAT_A: 8d748b58 FEAT_B: Bug Measurer (Activity)_4090 - Correlation: 0.9999999999999998
# 255: FEAT_A: e57dd7af FEAT_B: 763fc34e - Correlation: 0.9972721980394412
# 256: FEAT_A: e57dd7af FEAT_B: Leaf Leader_3120 - Correlation: 1.0
# 257: FEAT_A: e57dd7af FEAT_B: Leaf Leader_3020 - Correlation: 0.9972721980394412
# 258: FEAT_A: a1e4395d FEAT_B: a52b92d5 - Correlation: 0.9991003891313368
# 259: FEAT_A: a1e4395d FEAT_B: Mushroom Sorter (Assessment)_3110 - Correlation: 0.9991003891313368
# 260: FEAT_A: a1e4395d FEAT_B: Mushroom Sorter (Assessment)_3010 - Correlation: 1.0
# 261: FEAT_A: 565a3990 FEAT_B: Bug Measurer (Activity)_4070 - Correlation: 1.0
# 262: FEAT_A: d2278a3b FEAT_B: Bottle Filler (Activity)_2000 - Correlation: 1.0
# 263: FEAT_A: d45ed6a1 FEAT_B: c277e121 - Correlation: 0.9979692879543319
# 264: FEAT_A: d45ed6a1 FEAT_B: b120f2ac - Correlation: 0.9979707847816691
# 265: FEAT_A: d45ed6a1 FEAT_B: All Star Sorting_3120 - Correlation: 1.0
# 266: FEAT_A: d45ed6a1 FEAT_B: All Star Sorting_3020 - Correlation: 0.9979692879543319
# 267: FEAT_A: d45ed6a1 FEAT_B: All Star Sorting_2025 - Correlation: 0.9979707847816691
# 268: FEAT_A: 8fee50e2 FEAT_B: Bird Measurer (Assessment)_4020 - Correlation: 1.0
# 269: FEAT_A: 15a43e5b FEAT_B: Bottle Filler (Activity)_4070 - Correlation: 1.0
# 270: FEAT_A: df4fe8b6 FEAT_B: ea296733 - Correlation: 0.9972489515829078
# 271: FEAT_A: df4fe8b6 FEAT_B: Chest Sorter (Assessment)_3120 - Correlation: 1.0
# 272: FEAT_A: df4fe8b6 FEAT_B: Chest Sorter (Assessment)_3020 - Correlation: 0.9972489515829078
# 273: FEAT_A: df4fe8b6 FEAT_B: chest_assessment_uncorrect_sum - Correlation: 1.0
# 274: FEAT_A: c189aaf2 FEAT_B: Happy Camel_2083 - Correlation: 0.9999999999999999
# 275: FEAT_A: 8d84fa81 FEAT_B: Bubble Bath_4010 - Correlation: 1.0
# 276: FEAT_A: 160654fd FEAT_B: 88d4a5be - Correlation: 0.9989297172615879
# 277: FEAT_A: 160654fd FEAT_B: Mushroom Sorter (Assessment)_3020 - Correlation: 1.0
# 278: FEAT_A: 160654fd FEAT_B: Mushroom Sorter (Assessment)_3120 - Correlation: 0.9989297172615879
# 279: FEAT_A: 30df3273 FEAT_B: Sandcastle Builder (Activity)_4080 - Correlation: 1.0
# 280: FEAT_A: a0faea5d FEAT_B: Bubble Bath_4070 - Correlation: 1.0
# 281: FEAT_A: beb0a7b9 FEAT_B: b88f38da - Correlation: 0.9999125179829754
# 282: FEAT_A: beb0a7b9 FEAT_B: Fireworks (Activity)_3110 - Correlation: 0.9999125179829754
# 283: FEAT_A: beb0a7b9 FEAT_B: Fireworks (Activity)_3010 - Correlation: 1.0
# 284: FEAT_A: 37937459 FEAT_B: Sandcastle Builder (Activity)_4090 - Correlation: 0.9999999999999998
# 285: FEAT_A: 53c6e11a FEAT_B: Leaf Leader_2075 - Correlation: 0.9999999999999999
# 286: FEAT_A: 4a4c3d21 FEAT_B: Bird Measurer (Assessment)_4025 - Correlation: 1.0
# 287: FEAT_A: 29f54413 FEAT_B: Leaf Leader_2060 - Correlation: 0.9999999999999998
# 288: FEAT_A: ecc36b7f FEAT_B: Bubble Bath_4095 - Correlation: 1.0
# 289: FEAT_A: 46cd75b4 FEAT_B: Chicken Balancer (Activity)_4022 - Correlation: 0.9999999999999998
# 290: FEAT_A: fbaf3456 FEAT_B: Mushroom Sorter (Assessment)_4030 - Correlation: 0.9999999999999999
# 291: FEAT_A: 1af8be29 FEAT_B: 3bf1cf26 - Correlation: 0.9998900847287077
# 292: FEAT_A: 1af8be29 FEAT_B: Happy Camel_3120 - Correlation: 0.9998900847287077
# 293: FEAT_A: 1af8be29 FEAT_B: Happy Camel_3020 - Correlation: 0.9999999999999999
# 294: FEAT_A: 76babcde FEAT_B: Dino Dive_4070 - Correlation: 1.0
# 295: FEAT_A: 6f4adc4b FEAT_B: 55115cbd - Correlation: 0.9997831892615398
# 296: FEAT_A: 6f4adc4b FEAT_B: Bubble Bath_3121 - Correlation: 0.9997831892615398
# 297: FEAT_A: 6f4adc4b FEAT_B: Bubble Bath_3021 - Correlation: 1.0
# 298: FEAT_A: bdf49a58 FEAT_B: 1375ccb7 - Correlation: 0.9993801763820347
# 299: FEAT_A: bdf49a58 FEAT_B: Bird Measurer (Assessment)_3010 - Correlation: 0.9993801763820347
# 300: FEAT_A: bdf49a58 FEAT_B: Bird Measurer (Assessment)_3110 - Correlation: 1.0
# 301: FEAT_A: 91561152 FEAT_B: Cauldron Filler (Assessment)_4025 - Correlation: 1.0
# 302: FEAT_A: 77c76bc5 FEAT_B: Cauldron Filler (Assessment)_4090 - Correlation: 1.0
# 303: FEAT_A: ecc6157f FEAT_B: Cart Balancer (Assessment)_4080 - Correlation: 0.9999999999999999
# 304: FEAT_A: 49ed92e9 FEAT_B: bd701df8 - Correlation: 0.9993109138888533
# 305: FEAT_A: 49ed92e9 FEAT_B: Watering Hole (Activity)_3010 - Correlation: 1.0
# 306: FEAT_A: 49ed92e9 FEAT_B: Watering Hole (Activity)_3110 - Correlation: 0.9993109138888533
# 307: FEAT_A: 0ce40006 FEAT_B: Happy Camel_4080 - Correlation: 1.0
# 308: FEAT_A: 87d743c1 FEAT_B: Dino Dive_4010 - Correlation: 1.0
# 309: FEAT_A: 1f19558b FEAT_B: ca11f653 - Correlation: 0.998316427341082
# 310: FEAT_A: 1f19558b FEAT_B: daac11b0 - Correlation: 0.9991356096406655
# 311: FEAT_A: 1f19558b FEAT_B: All Star Sorting_3021 - Correlation: 0.9991356096406655
# 312: FEAT_A: 1f19558b FEAT_B: All Star Sorting_2030 - Correlation: 0.998316427341082
# 313: FEAT_A: 1f19558b FEAT_B: All Star Sorting_3121 - Correlation: 1.0
# 314: FEAT_A: 7f0836bf FEAT_B: a29c5338 - Correlation: 0.9986531654717627
# 315: FEAT_A: 7f0836bf FEAT_B: Dino Drink_3110 - Correlation: 1.0
# 316: FEAT_A: 7f0836bf FEAT_B: Dino Drink_3010 - Correlation: 0.9986531654717627
# 317: FEAT_A: a1bbe385 FEAT_B: f28c589a - Correlation: 0.999953679734225
# 318: FEAT_A: a1bbe385 FEAT_B: Air Show_3110 - Correlation: 1.0
# 319: FEAT_A: a1bbe385 FEAT_B: Air Show_3010 - Correlation: 0.999953679734225
# 320: FEAT_A: 77261ab5 FEAT_B: Sandcastle Builder (Activity)_2000 - Correlation: 0.9999999999999999
# 321: FEAT_A: 828e68f9 FEAT_B: Cart Balancer (Assessment)_3110 - Correlation: 1.0
# 322: FEAT_A: dcb55a27 FEAT_B: Air Show_4110 - Correlation: 1.0
# 323: FEAT_A: d3640339 FEAT_B: Dino Dive_4090 - Correlation: 1.0
# 324: FEAT_A: 792530f8 FEAT_B: Dino Drink_4030 - Correlation: 1.0
# 325: FEAT_A: 4d6737eb FEAT_B: Dino Drink_2070 - Correlation: 1.0
# 326: FEAT_A: 01ca3a3c FEAT_B: Leaf Leader_4080 - Correlation: 0.9999999999999999
# 327: FEAT_A: e79f3763 FEAT_B: Bug Measurer (Activity)_4030 - Correlation: 1.0
# 328: FEAT_A: 84538528 FEAT_B: Sandcastle Builder (Activity)_4020 - Correlation: 1.0
# 329: FEAT_A: 19967db1 FEAT_B: Chow Time_4090 - Correlation: 1.0
# 330: FEAT_A: c952eb01 FEAT_B: Watering Hole (Activity)_4070 - Correlation: 1.0
# 331: FEAT_A: 89aace00 FEAT_B: e5734469 - Correlation: 0.9998406115110345
# 332: FEAT_A: 89aace00 FEAT_B: Dino Drink_3020 - Correlation: 0.9998406115110345
# 333: FEAT_A: 89aace00 FEAT_B: Dino Drink_3120 - Correlation: 1.0
# 334: FEAT_A: f3cd5473 FEAT_B: Pan Balance_4070 - Correlation: 1.0
# 335: FEAT_A: acf5c23f FEAT_B: Cart Balancer (Assessment)_4070 - Correlation: 1.0
# 336: FEAT_A: 46b50ba8 FEAT_B: Happy Camel_4095 - Correlation: 0.9999999999999998
# 337: FEAT_A: 9554a50b FEAT_B: Cauldron Filler (Assessment)_4080 - Correlation: 0.9999999999999999
# 338: FEAT_A: cdd22e43 FEAT_B: Chicken Balancer (Activity)_4035 - Correlation: 1.0
# 339: FEAT_A: 7d093bf9 FEAT_B: Chow Time_2000 - Correlation: 0.9999999999999999
# 340: FEAT_A: 5d042115 FEAT_B: Flower Waterer (Activity)_4030 - Correlation: 1.0
# 341: FEAT_A: 15f99afc FEAT_B: 6cf7d25c - Correlation: 0.9994848234397947
# 342: FEAT_A: 15f99afc FEAT_B: Pan Balance_3110 - Correlation: 1.0
# 343: FEAT_A: 15f99afc FEAT_B: Pan Balance_3010 - Correlation: 0.9994848234397947
# 344: FEAT_A: 392e14df FEAT_B: Cauldron Filler (Assessment)_4100 - Correlation: 1.0
# 345: FEAT_A: 499edb7c FEAT_B: Chicken Balancer (Activity)_4020 - Correlation: 1.0
# 346: FEAT_A: 3bfd1a65 FEAT_B: db02c830 - Correlation: 0.9999982205265872
# 347: FEAT_A: 3bfd1a65 FEAT_B: Mushroom Sorter (Assessment)_2000 - Correlation: 1.0
# 348: FEAT_A: 3bfd1a65 FEAT_B: Mushroom Sorter (Assessment)_2025 - Correlation: 0.9999982205265872
# 349: FEAT_A: 5e3ea25a FEAT_B: Crystals Rule_4070 - Correlation: 1.0
# 350: FEAT_A: 56bcd38d FEAT_B: Chicken Balancer (Activity)_4030 - Correlation: 0.9999999999999998
# 351: FEAT_A: 0d1da71f FEAT_B: Chow Time_3110 - Correlation: 1.0
# 352: FEAT_A: 7ad3efc6 FEAT_B: 65a38bf7 - Correlation: 0.999978626569043
# 353: FEAT_A: 7ad3efc6 FEAT_B: Cart Balancer (Assessment)_2020 - Correlation: 0.999978626569043
# 354: FEAT_A: 7ad3efc6 FEAT_B: Cart Balancer (Assessment)_2000 - Correlation: 1.0
# 355: FEAT_A: 93b353f2 FEAT_B: Chest Sorter (Assessment)_4100 - Correlation: 0.9999999999999998
# 356: FEAT_A: 5c2f29ca FEAT_B: Cart Balancer (Assessment)_4020 - Correlation: 1.0
# 357: FEAT_A: d122731b FEAT_B: Cart Balancer (Assessment)_4100 - Correlation: 0.9999999999999998
# 358: FEAT_A: 13f56524 FEAT_B: Mushroom Sorter (Assessment)_4080 - Correlation: 1.0
# 359: FEAT_A: 756e5507 FEAT_B: Chicken Balancer (Activity)_2000 - Correlation: 1.0
# 360: FEAT_A: 857f21c0 FEAT_B: Bubble Bath_4040 - Correlation: 1.0
# 361: FEAT_A: 4bb2f698 FEAT_B: Chicken Balancer (Activity)_4070 - Correlation: 0.9999999999999998
# 362: FEAT_A: 6aeafed4 FEAT_B: Bubble Bath_4090 - Correlation: 1.0
# 363: FEAT_A: 00c73085 FEAT_B: Dino Dive_2030 - Correlation: 0.9999999999999999
# 364: FEAT_A: 7fd1ac25 FEAT_B: Egg Dropper (Activity)_4080 - Correlation: 1.0
# 365: FEAT_A: 0d18d96c FEAT_B: Mushroom Sorter (Assessment)_4035 - Correlation: 1.0
# 366: FEAT_A: 804ee27f FEAT_B: Pan Balance_4020 - Correlation: 1.0
# 367: FEAT_A: 99abe2bb FEAT_B: Bubble Bath_2080 - Correlation: 1.0
# 368: FEAT_A: bd612267 FEAT_B: Chest Sorter (Assessment)_4070 - Correlation: 0.9999999999999999
# 369: FEAT_A: 2a444e03 FEAT_B: Pan Balance_4030 - Correlation: 1.0
# 370: FEAT_A: 7961e599 FEAT_B: Dino Dive_2020 - Correlation: 0.9999999999999999
# 371: FEAT_A: 47efca07 FEAT_B: Bottle Filler (Activity)_4090 - Correlation: 1.0
# 372: FEAT_A: 6d90d394 FEAT_B: Scrub-A-Dub_2000 - Correlation: 0.9999999999999999
# 373: FEAT_A: 3afb49e6 FEAT_B: e4f1efe6 - Correlation: 0.9985179906980775
# 374: FEAT_A: 3afb49e6 FEAT_B: Chest Sorter (Assessment)_3121 - Correlation: 0.9985179906980775
# 375: FEAT_A: 3afb49e6 FEAT_B: Chest Sorter (Assessment)_3021 - Correlation: 1.0
# 376: FEAT_A: 1325467d FEAT_B: Sandcastle Builder (Activity)_4070 - Correlation: 1.0
# 377: FEAT_A: e7561dd2 FEAT_B: Pan Balance_4025 - Correlation: 0.9999999999999998
# 378: FEAT_A: 5e812b27 FEAT_B: Sandcastle Builder (Activity)_4030 - Correlation: 1.0
# 379: FEAT_A: 29bdd9ba FEAT_B: Dino Dive_2000 - Correlation: 1.0
# 380: FEAT_A: 92687c59 FEAT_B: Scrub-A-Dub_4090 - Correlation: 1.0
# 381: FEAT_A: 6bf9e3e1 FEAT_B: Happy Camel_4040 - Correlation: 0.9999999999999999
# 382: FEAT_A: 1575e76c FEAT_B: Air Show_2020 - Correlation: 1.0
# 383: FEAT_A: a5e9da97 FEAT_B: Pan Balance_4100 - Correlation: 1.0
# 384: FEAT_A: c58186bf FEAT_B: Sandcastle Builder (Activity)_4035 - Correlation: 1.0
# 385: FEAT_A: 45d01abe FEAT_B: 7525289a - Correlation: 0.9981555049446889
# 386: FEAT_A: 45d01abe FEAT_B: Bird Measurer (Assessment)_3021 - Correlation: 1.0
# 387: FEAT_A: 45d01abe FEAT_B: Bird Measurer (Assessment)_3121 - Correlation: 0.9981555049446889
# 388: FEAT_A: e694a35b FEAT_B: Fireworks (Activity)_4020 - Correlation: 1.0
# 389: FEAT_A: a76029ee FEAT_B: Bird Measurer (Assessment)_4040 - Correlation: 0.9999999999999999
# 390: FEAT_A: 884228c8 FEAT_B: Fireworks (Activity)_4070 - Correlation: 1.0
# 391: FEAT_A: 93edfe2e FEAT_B: Crystals Rule_4090 - Correlation: 1.0
# 392: FEAT_A: df4940d3 FEAT_B: 67439901 - Correlation: 0.999935162643595
# 393: FEAT_A: df4940d3 FEAT_B: Bottle Filler (Activity)_3010 - Correlation: 0.999935162643595
# 394: FEAT_A: df4940d3 FEAT_B: Bottle Filler (Activity)_3110 - Correlation: 0.9999999999999999
# 395: FEAT_A: a44b10dc FEAT_B: Flower Waterer (Activity)_4070 - Correlation: 1.0
# 396: FEAT_A: 6088b756 FEAT_B: Dino Dive_2070 - Correlation: 1.0
# 397: FEAT_A: 3edf6747 FEAT_B: Cauldron Filler (Assessment)_4035 - Correlation: 0.9999999999999999
# 398: FEAT_A: 67aa2ada FEAT_B: Leaf Leader_4090 - Correlation: 1.0
# 399: FEAT_A: 907a054b FEAT_B: c51d8688 - Correlation: 0.9999667370361688
# 400: FEAT_A: 907a054b FEAT_B: Pan Balance_3020 - Correlation: 1.0
# 401: FEAT_A: 907a054b FEAT_B: Pan Balance_3120 - Correlation: 0.9999667370361688
# 402: FEAT_A: cc5087a3 FEAT_B: Crystals Rule_4010 - Correlation: 1.0
# 403: FEAT_A: 6f4bd64e FEAT_B: Air Show_4090 - Correlation: 0.9999999999999998
# 404: FEAT_A: 5f5b2617 FEAT_B: Bottle Filler (Activity)_4080 - Correlation: 1.0
# 405: FEAT_A: 5c3d2b2f FEAT_B: Scrub-A-Dub_4020 - Correlation: 1.0
# 406: FEAT_A: d9c005dd FEAT_B: Happy Camel_2000 - Correlation: 1.0
# 407: FEAT_A: 9ee1c98c FEAT_B: Sandcastle Builder (Activity)_4021 - Correlation: 0.9999999999999999
# 408: FEAT_A: 29a42aea FEAT_B: Bubble Bath_4080 - Correlation: 1.0
# 409: FEAT_A: 562cec5f FEAT_B: Chest Sorter (Assessment)_4025 - Correlation: 1.0
# 410: FEAT_A: d88e8f25 FEAT_B: ac92046e - Correlation: 0.9999763070332106
# 411: FEAT_A: d88e8f25 FEAT_B: Scrub-A-Dub_3020 - Correlation: 1.0
# 412: FEAT_A: d88e8f25 FEAT_B: Scrub-A-Dub_3120 - Correlation: 0.9999763070332106
# 413: FEAT_A: 6077cc36 FEAT_B: Bird Measurer (Assessment)_4080 - Correlation: 0.9999999999999998
# 414: FEAT_A: a16a373e FEAT_B: Bird Measurer (Assessment)_4070 - Correlation: 1.0
# 415: FEAT_A: b1d5101d FEAT_B: All Star Sorting_4095 - Correlation: 1.0
# 416: FEAT_A: 4b5efe37 FEAT_B: b7dc8128 - Correlation: 0.9980151285383981
# 417: FEAT_A: 4b5efe37 FEAT_B: All Star Sorting_4010 - Correlation: 1.0
# 418: FEAT_A: 4b5efe37 FEAT_B: All Star Sorting_2000 - Correlation: 0.9980151285383981
# 419: FEAT_A: 7040c096 FEAT_B: Scrub-A-Dub_4010 - Correlation: 1.0
# 420: FEAT_A: 4ef8cdd3 FEAT_B: Chow Time_4020 - Correlation: 1.0
# 421: FEAT_A: 90efca10 FEAT_B: Bottle Filler (Activity)_4020 - Correlation: 1.0
# 422: FEAT_A: 3bb91ced FEAT_B: Happy Camel_2081 - Correlation: 1.0
# 423: FEAT_A: 9e34ea74 FEAT_B: Egg Dropper (Activity)_4070 - Correlation: 1.0
# 424: FEAT_A: bcceccc6 FEAT_B: Air Show_4070 - Correlation: 1.0
# 425: FEAT_A: d02b7a8e FEAT_B: All Star Sorting_4035 - Correlation: 1.0
# 426: FEAT_A: 4e5fc6f5 FEAT_B: Cart Balancer (Assessment)_4090 - Correlation: 1.0
# 427: FEAT_A: 598f4598 FEAT_B: Flower Waterer (Activity)_4025 - Correlation: 0.9999999999999998
# 428: FEAT_A: 1b54d27f FEAT_B: Watering Hole (Activity)_2010 - Correlation: 1.0
# 429: FEAT_A: a8efe47b FEAT_B: Chest Sorter (Assessment)_4030 - Correlation: 1.0
# 430: FEAT_A: 85d1b0de FEAT_B: Chicken Balancer (Activity)_4090 - Correlation: 1.0
# 431: FEAT_A: b2dba42b FEAT_B: 1bb5fbdb - Correlation: 0.9999521729413294
# 432: FEAT_A: b2dba42b FEAT_B: Sandcastle Builder (Activity)_3110 - Correlation: 0.9999521729413294
# 433: FEAT_A: b2dba42b FEAT_B: Sandcastle Builder (Activity)_3010 - Correlation: 1.0
# 434: FEAT_A: 08ff79ad FEAT_B: Egg Dropper (Activity)_4090 - Correlation: 1.0
# 435: FEAT_A: 1cc7cfca FEAT_B: All Star Sorting_4030 - Correlation: 1.0
# 436: FEAT_A: f32856e4 FEAT_B: Leaf Leader_2020 - Correlation: 1.0
# 437: FEAT_A: f50fc6c1 FEAT_B: Watering Hole (Activity)_4021 - Correlation: 1.0
# 438: FEAT_A: bb3e370b FEAT_B: Bottle Filler (Activity) - Correlation: 0.9950043311420306
# 439: FEAT_A: bb3e370b FEAT_B: Bottle Filler (Activity)_4030 - Correlation: 0.9999999999999999
# 440: FEAT_A: 6c517a88 FEAT_B: Dino Drink_4070 - Correlation: 1.0
# 441: FEAT_A: eb2c19cd FEAT_B: Mushroom Sorter (Assessment)_4090 - Correlation: 1.0
# 442: FEAT_A: 731c0cbe FEAT_B: Bird Measurer (Assessment)_4090 - Correlation: 1.0
# 443: FEAT_A: 5f0eb72c FEAT_B: Mushroom Sorter (Assessment)_4020 - Correlation: 0.9999999999999998
# 444: FEAT_A: 8b757ab8 FEAT_B: 44cb4907 - Correlation: 0.999835058794711
# 445: FEAT_A: 8b757ab8 FEAT_B: Crystals Rule_3020 - Correlation: 0.999835058794711
# 446: FEAT_A: 8b757ab8 FEAT_B: Crystals Rule_3120 - Correlation: 1.0
# 447: FEAT_A: 3d63345e FEAT_B: Cart Balancer (Assessment)_4035 - Correlation: 1.0
# 448: FEAT_A: 3d0b9317 FEAT_B: Chest Sorter (Assessment)_4040 - Correlation: 1.0
# 449: FEAT_A: 9c5ef70c FEAT_B: Pan Balance_2000 - Correlation: 1.0
# 450: FEAT_A: 611485c5 FEAT_B: Fireworks (Activity)_4080 - Correlation: 1.0
# 451: FEAT_A: d3f1e122 FEAT_B: Bottle Filler (Activity)_4035 - Correlation: 1.0
# 452: FEAT_A: 7372e1a5 FEAT_B: Chow Time_4070 - Correlation: 1.0
# 453: FEAT_A: 5a848010 FEAT_B: Scrub-A-Dub_2080 - Correlation: 1.0
# 454: FEAT_A: 222660ff FEAT_B: 38074c54 - Correlation: 0.9999999999999998
# 455: FEAT_A: 222660ff FEAT_B: Chest Sorter (Assessment)_2030 - Correlation: 0.9999999999999998
# 456: FEAT_A: 222660ff FEAT_B: Chest Sorter (Assessment)_2010 - Correlation: 0.9999999999999998
# 457: FEAT_A: 7d5c30a2 FEAT_B: Dino Dive_2060 - Correlation: 1.0
# 458: FEAT_A: 9d4e7b25 FEAT_B: Cart Balancer (Assessment)_4040 - Correlation: 1.0
# 459: FEAT_A: 1beb320a FEAT_B: Bubble Bath_2020 - Correlation: 1.0
# 460: FEAT_A: 14de4c5d FEAT_B: Air Show_4100 - Correlation: 1.0
# 461: FEAT_A: 532a2afb FEAT_B: Cauldron Filler (Assessment)_2020 - Correlation: 1.0
# 462: FEAT_A: d88ca108 FEAT_B: Air Show_2070 - Correlation: 1.0
# 463: FEAT_A: 30614231 FEAT_B: 37ee8496 - Correlation: 0.9967763987631819
# 464: FEAT_A: 30614231 FEAT_B: Cauldron Filler (Assessment)_4020 - Correlation: 1.0
# 465: FEAT_A: 30614231 FEAT_B: Cauldron Filler (Assessment)_4030 - Correlation: 0.9967763987631819
# 466: FEAT_A: d51b1749 FEAT_B: Happy Camel_2080 - Correlation: 1.0
# 467: FEAT_A: 9e6b7fb5 FEAT_B: Chow Time_4095 - Correlation: 0.9999999999999998
# 468: FEAT_A: 461eace6 FEAT_B: Egg Dropper (Activity)_4020 - Correlation: 1.0
# 469: FEAT_A: 9b01374f FEAT_B: Flower Waterer (Activity)_2000 - Correlation: 1.0
# 470: FEAT_A: 86ba578b FEAT_B: Leaf Leader_2070 - Correlation: 1.0
# 471: FEAT_A: 4901243f FEAT_B: Fireworks (Activity)_2000 - Correlation: 1.0
# 472: FEAT_A: 795e4a37 FEAT_B: Cart Balancer (Assessment)_3010 - Correlation: 1.0
# 473: FEAT_A: cb1178ad FEAT_B: Chest Sorter (Assessment)_4090 - Correlation: 1.0
# 474: FEAT_A: e4d32835 FEAT_B: Pan Balance_4080 - Correlation: 0.9999999999999998
# 475: FEAT_A: 05ad839b FEAT_B: Happy Camel_4090 - Correlation: 1.0
# 476: FEAT_A: d38c2fd7 FEAT_B: Bird Measurer (Assessment)_4035 - Correlation: 0.9999999999999999
# 477: FEAT_A: f54238ee FEAT_B: Fireworks (Activity)_4090 - Correlation: 1.0
# 478: FEAT_A: 6043a2b4 FEAT_B: All Star Sorting_4090 - Correlation: 0.9999999999999999
# 479: FEAT_A: e64e2cfd FEAT_B: Watering Hole (Activity)_2000 - Correlation: 0.9999999999999998
# 480: FEAT_A: 99ea62f3 FEAT_B: Bubble Bath_2083 - Correlation: 1.0
# 481: FEAT_A: 9ed8f6da FEAT_B: Dino Drink_2075 - Correlation: 0.9999999999999999
# 482: FEAT_A: de26c3a6 FEAT_B: Flower Waterer (Activity)_4020 - Correlation: 0.9999999999999999
# 483: FEAT_A: bfc77bd6 FEAT_B: Chest Sorter (Assessment)_4080 - Correlation: 0.9999999999999998
# 484: FEAT_A: 3393b68b FEAT_B: Bird Measurer (Assessment)_2010 - Correlation: 1.0
# 485: FEAT_A: c7f7f0e1 FEAT_B: Bug Measurer (Activity)_2000 - Correlation: 1.0
# 486: FEAT_A: e080a381 FEAT_B: Pan Balance_4090 - Correlation: 1.0
# 487: FEAT_A: Welcome to Lost Lagoon! FEAT_B: Welcome to Lost Lagoon!_2000 - Correlation: 1.0
# 488: FEAT_A: Welcome to Lost Lagoon! FEAT_B: Clip_NONE - Correlation: 1.0
# 489: FEAT_A: Costume Box FEAT_B: Costume Box_2000 - Correlation: 1.0
# 490: FEAT_A: Ordering Spheres FEAT_B: Ordering Spheres_2000 - Correlation: 1.0
# 491: FEAT_A: Tree Top City - Level 2 FEAT_B: Tree Top City - Level 2_2000 - Correlation: 1.0
# 492: FEAT_A: Pirate's Tale FEAT_B: Pirate's Tale_2000 - Correlation: 0.9999999999999999
# 493: FEAT_A: Lifting Heavy Things FEAT_B: Lifting Heavy Things_2000 - Correlation: 0.9999999999999999
# 494: FEAT_A: Heavy, Heavier, Heaviest FEAT_B: Heavy, Heavier, Heaviest_2000 - Correlation: 1.0
# 495: FEAT_A: Tree Top City - Level 3 FEAT_B: Tree Top City - Level 3_2000 - Correlation: 1.0
# 496: FEAT_A: Cauldron Filler (Assessment) FEAT_B: Assessment_MAGMAPEAK - Correlation: 1.0
# 497: FEAT_A: Slop Problem FEAT_B: Slop Problem_2000 - Correlation: 1.0
# 498: FEAT_A: Tree Top City - Level 1 FEAT_B: Tree Top City - Level 1_2000 - Correlation: 0.9999999999999999
# 499: FEAT_A: Balancing Act FEAT_B: Balancing Act_2000 - Correlation: 1.0
# 500: FEAT_A: Magma Peak - Level 1 FEAT_B: Magma Peak - Level 1_2000 - Correlation: 1.0
# 501: FEAT_A: Rulers FEAT_B: Rulers_2000 - Correlation: 1.0
# 502: FEAT_A: Honey Cake FEAT_B: Honey Cake_2000 - Correlation: 1.0
# 503: FEAT_A: Magma Peak - Level 2 FEAT_B: Magma Peak - Level 2_2000 - Correlation: 1.0
# 504: FEAT_A: 12 Monkeys FEAT_B: 12 Monkeys_2000 - Correlation: 1.0
# 505: FEAT_A: Crystal Caves - Level 3 FEAT_B: Crystal Caves - Level 3_2000 - Correlation: 1.0
# 506: FEAT_A: Crystal Caves - Level 2 FEAT_B: Crystal Caves - Level 2_2000 - Correlation: 1.0
# 507: FEAT_A: Treasure Map FEAT_B: Treasure Map_2000 - Correlation: 1.0
# 508: FEAT_A: Crystal Caves - Level 1 FEAT_B: Crystal Caves - Level 1_2000 - Correlation: 1.0
# 509: FEAT_A: var_event_id FEAT_B: var_title_event_code - Correlation: 0.9995254184300616

# %%
# to_exclude = [] 
# ajusted_test = reduce_test.copy()
# for feature in ajusted_test.columns:
#     if feature not in ['accuracy_group', 'installation_id', 'accuracy_group', 'session_title']:
#         data = reduce_train[feature]
#         train_mean = data.mean()
#         data = ajusted_test[feature] 
#         test_mean = data.mean()
#         try:
#             error = stract_hists(feature, adjust=True)
#             ajust_factor = train_mean / test_mean
#             if ajust_factor > 10 or ajust_factor < 0.1:# or error > 0.01:
#                 to_exclude.append(feature)
#                 print(feature, train_mean, test_mean, error)
#             else:
#                 ajusted_test[feature] *= ajust_factor
#         except:
#             to_exclude.append(feature)
#             print(feature, train_mean, test_mean)

# %%
# features = [x for x in features if x not in (to_remove)]
reduce_train[features].shape
# Out:
# (17690, 916)

# %%
# solve: LightGBMError: Do not support special JSON characters in feature name.
reduce_train.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in reduce_train.columns]
ajusted_test.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in ajusted_test.columns]
features = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in features]


def LGB_CV(
          max_depth,
          learning_rate,
          bagging_freq,
          bagging_fraction,
          colsample_bytree,
#           feature_fraction,
          lambda_l1,
          lambda_l2,
          target='accuracy_group',
          categoricals=['session_title']
         ):
    train_df = reduce_train

    folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=15)
#     folds = GroupKFold(n_splits=5)
    
    cv = folds.split(reduce_train, reduce_train[target])
    
    param = {
        'objective':'regression',
        "boosting_type": "gbdt",
        'metric': 'rmse',
        'eval_metric': 'cappa',
        "bagging_seed": 11,
        "metric": 'rmse',
        'early_stopping_rounds': 150,
        'verbose': 100,
        "verbosity": -1,
        'seed': 42,
        'bagging_freq': int(bagging_freq),
        'colsample_bytree': colsample_bytree,
        'max_depth': int(max_depth),
        'learning_rate': learning_rate,
#         "feature_fraction": feature_fraction,
        "bagging_fraction": bagging_fraction,
        "lambda_l1": lambda_l1,
        "lambda_l2": lambda_l2,
    }
    
    
    oof_pred = np.zeros(train_df.shape[0])
    for fold, (train_idx, val_idx) in enumerate(cv):
        
        x_train, x_val = train_df[features].iloc[train_idx], train_df[features].iloc[val_idx]   
        y_train, y_val = train_df[target][train_idx], train_df[target][val_idx]

        train_set = lgb.Dataset(x_train, y_train, categorical_feature=categoricals)
        val_set = lgb.Dataset(x_val, y_val, categorical_feature=categoricals)
        
        clf = lgb.train(param, train_set, 10000, valid_sets = [train_set, val_set], verbose_eval=100, early_stopping_rounds=100)
        
        oof_pred[val_idx] = clf.predict(train_df.iloc[val_idx][features], num_iteration=clf.best_iteration)
        
        print('Partial score of fold {} is: {}'.format(fold, eval_qwk_lgb_regr(y_val, oof_pred[val_idx])[1]))
        
        del clf, train_idx, val_idx
        gc.collect()
    _, loss_score, _ = eval_qwk_lgb_regr(train_df[target], oof_pred)
    print('The score is {}'.format(loss_score))
#     return -mean_squared_error(oof, target)**0.5
    return loss_score

LGB_BO = BayesianOptimization(LGB_CV, {
    'max_depth': (8, 12),
#     'feature_fraction': (0.4, 1.0),
    'bagging_freq': (1, 10),
    'bagging_fraction': (0.4, 1.0),
    'lambda_l1': (0, 6),
    'lambda_l2': (0, 6),
    'learning_rate': (0.025, 0.1),
    'colsample_bytree': (0.4, 0.6)
    })

print('-'*126)

start_time = timer(None)
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    LGB_BO.maximize(init_points=2, n_iter=20, acq='ei', xi=0.0, random_state=1000)
timer(start_time)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------
# |   iter    |  target   | baggin... | baggin... | colsam... | lambda_l1 | lambda_l2 | learni... | max_depth |
# -------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.904989	valid_1's rmse: 0.999009
# [200]	training's rmse: 0.839892	valid_1's rmse: 0.996225
# [300]	training's rmse: 0.792483	valid_1's rmse: 0.999768
# Early stopping, best iteration is:
# [168]	training's rmse: 0.857788	valid_1's rmse: 0.99548
# Partial score of fold 0 is: 0.5771779186404624
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.90664	valid_1's rmse: 0.988839
# [200]	training's rmse: 0.843322	valid_1's rmse: 0.983983
# [300]	training's rmse: 0.795832	valid_1's rmse: 0.984569
# Early stopping, best iteration is:
# [197]	training's rmse: 0.844936	valid_1's rmse: 0.983817
# Partial score of fold 1 is: 0.5957871003845977
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.912562	valid_1's rmse: 0.991638
# [200]	training's rmse: 0.845669	valid_1's rmse: 0.982736
# [300]	training's rmse: 0.797664	valid_1's rmse: 0.982127
# [400]	training's rmse: 0.758038	valid_1's rmse: 0.983612
# Early stopping, best iteration is:
# [320]	training's rmse: 0.788831	valid_1's rmse: 0.982014
# Partial score of fold 2 is: 0.5954292315049028
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.911981	valid_1's rmse: 0.978787
# [200]	training's rmse: 0.84704	valid_1's rmse: 0.971186
# [300]	training's rmse: 0.800553	valid_1's rmse: 0.970827
# [400]	training's rmse: 0.761067	valid_1's rmse: 0.971313
# Early stopping, best iteration is:
# [266]	training's rmse: 0.815378	valid_1's rmse: 0.970075
# Partial score of fold 3 is: 0.5993657891815468
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.907826	valid_1's rmse: 0.985119
# [200]	training's rmse: 0.843689	valid_1's rmse: 0.980361
# [300]	training's rmse: 0.796356	valid_1's rmse: 0.982323
# Early stopping, best iteration is:
# [174]	training's rmse: 0.857903	valid_1's rmse: 0.979801
# Partial score of fold 4 is: 0.5947923725711174
# The score is 0.5933848419433594
# |  1        |  0.5934   |  0.9685   |  5.726    |  0.5973   |  5.376    |  0.1255   |  0.04458  |  11.69    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.854719	valid_1's rmse: 0.999763
# [200]	training's rmse: 0.775639	valid_1's rmse: 1.00368
# Early stopping, best iteration is:
# [67]	training's rmse: 0.89126	valid_1's rmse: 0.999168
# Partial score of fold 0 is: 0.5719888198848861
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.861216	valid_1's rmse: 0.988106
# [200]	training's rmse: 0.779597	valid_1's rmse: 0.988563
# Early stopping, best iteration is:
# [128]	training's rmse: 0.833667	valid_1's rmse: 0.986113
# Partial score of fold 1 is: 0.594713493745513
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.862844	valid_1's rmse: 0.988326
# [200]	training's rmse: 0.778172	valid_1's rmse: 0.988711
# [300]	training's rmse: 0.71843	valid_1's rmse: 0.99292
# Early stopping, best iteration is:
# [150]	training's rmse: 0.815339	valid_1's rmse: 0.985303
# Partial score of fold 2 is: 0.5984711169823096
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.861994	valid_1's rmse: 0.971098
# [200]	training's rmse: 0.782731	valid_1's rmse: 0.969456
# [300]	training's rmse: 0.722715	valid_1's rmse: 0.971002
# Early stopping, best iteration is:
# [156]	training's rmse: 0.813524	valid_1's rmse: 0.968376
# Partial score of fold 3 is: 0.6013340680198689
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.859608	valid_1's rmse: 0.987402
# [200]	training's rmse: 0.779995	valid_1's rmse: 0.988335
# Early stopping, best iteration is:
# [91]	training's rmse: 0.868165	valid_1's rmse: 0.986677
# Partial score of fold 4 is: 0.5870063911826275
# The score is 0.5906736627685896
# |  2        |  0.5907   |  0.8735   |  9.232    |  0.504    |  5.53     |  1.687    |  0.08348  |  8.484    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.868239	valid_1's rmse: 0.997542
# [200]	training's rmse: 0.79049	valid_1's rmse: 0.998816
# Early stopping, best iteration is:
# [104]	training's rmse: 0.864641	valid_1's rmse: 0.996829
# Partial score of fold 0 is: 0.5732413609638183
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.87212	valid_1's rmse: 0.988218
# [200]	training's rmse: 0.791831	valid_1's rmse: 0.986138
# [300]	training's rmse: 0.732258	valid_1's rmse: 0.989049
# Early stopping, best iteration is:
# [171]	training's rmse: 0.81193	valid_1's rmse: 0.9851
# Partial score of fold 1 is: 0.5938188215462756
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.881154	valid_1's rmse: 0.994414
# [200]	training's rmse: 0.794879	valid_1's rmse: 0.98436
# [300]	training's rmse: 0.735762	valid_1's rmse: 0.985533
# Early stopping, best iteration is:
# [182]	training's rmse: 0.806348	valid_1's rmse: 0.984004
# Partial score of fold 2 is: 0.5990079203018519
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.87453	valid_1's rmse: 0.977027
# [200]	training's rmse: 0.796709	valid_1's rmse: 0.973051
# [300]	training's rmse: 0.736634	valid_1's rmse: 0.975151
# Early stopping, best iteration is:
# [219]	training's rmse: 0.784289	valid_1's rmse: 0.972791
# Partial score of fold 3 is: 0.6007972647003265
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.869953	valid_1's rmse: 0.98607
# [200]	training's rmse: 0.790981	valid_1's rmse: 0.986103
# Early stopping, best iteration is:
# [141]	training's rmse: 0.834206	valid_1's rmse: 0.983789
# Partial score of fold 4 is: 0.5927337131683938
# The score is 0.5912374157059332
# |  3        |  0.5912   |  0.9812   |  1.13     |  0.4238   |  0.07996  |  5.365    |  0.06548  |  11.99    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.862839	valid_1's rmse: 0.999886
# [200]	training's rmse: 0.783527	valid_1's rmse: 1.00717
# Early stopping, best iteration is:
# [108]	training's rmse: 0.854695	valid_1's rmse: 0.999136
# Partial score of fold 0 is: 0.5696626721668692
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.868693	valid_1's rmse: 0.989755
# [200]	training's rmse: 0.78773	valid_1's rmse: 0.991532
# Early stopping, best iteration is:
# [133]	training's rmse: 0.837438	valid_1's rmse: 0.98813
# Partial score of fold 1 is: 0.5948924281853605
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.874038	valid_1's rmse: 0.994122
# [200]	training's rmse: 0.78881	valid_1's rmse: 0.988755
# Early stopping, best iteration is:
# [145]	training's rmse: 0.829425	valid_1's rmse: 0.987587
# Partial score of fold 2 is: 0.5959660348244451
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.869949	valid_1's rmse: 0.977357
# [200]	training's rmse: 0.789794	valid_1's rmse: 0.97729
# [300]	training's rmse: 0.728972	valid_1's rmse: 0.97909
# Early stopping, best iteration is:
# [152]	training's rmse: 0.824159	valid_1's rmse: 0.976526
# Partial score of fold 3 is: 0.5932820182267333
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.867314	valid_1's rmse: 0.989688
# [200]	training's rmse: 0.787761	valid_1's rmse: 0.991608
# Early stopping, best iteration is:
# [83]	training's rmse: 0.885293	valid_1's rmse: 0.98858
# Partial score of fold 4 is: 0.5891541369272899
# The score is 0.5877657432887609
# |  4        |  0.5878   |  0.613    |  1.029    |  0.411    |  0.322    |  0.04966  |  0.06758  |  11.77    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.842772	valid_1's rmse: 0.995942
# [200]	training's rmse: 0.759635	valid_1's rmse: 1.00275
# Early stopping, best iteration is:
# [103]	training's rmse: 0.839941	valid_1's rmse: 0.995571
# Partial score of fold 0 is: 0.57664111532092
# Partial score of fold 1 is: 0.5968607070236824
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.955724	valid_1's rmse: 1.01019
# [200]	training's rmse: 0.888877	valid_1's rmse: 0.983115
# [300]	training's rmse: 0.848793	valid_1's rmse: 0.980281
# [400]	training's rmse: 0.816987	valid_1's rmse: 0.980663
# Early stopping, best iteration is:
# [326]	training's rmse: 0.840054	valid_1's rmse: 0.979639
# Partial score of fold 2 is: 0.6009761991401739
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.949451	valid_1's rmse: 0.990588
# [200]	training's rmse: 0.89061	valid_1's rmse: 0.971664
# [300]	training's rmse: 0.852689	valid_1's rmse: 0.968134
# [400]	training's rmse: 0.820912	valid_1's rmse: 0.966874
# [500]	training's rmse: 0.794152	valid_1's rmse: 0.967352
# Early stopping, best iteration is:
# [362]	training's rmse: 0.832525	valid_1's rmse: 0.966432
# Partial score of fold 3 is: 0.6074178389746823
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.946369	valid_1's rmse: 0.999474
# [200]	training's rmse: 0.887579	valid_1's rmse: 0.982827
# [300]	training's rmse: 0.849068	valid_1's rmse: 0.981125
# Early stopping, best iteration is:
# [236]	training's rmse: 0.872403	valid_1's rmse: 0.980741
# Partial score of fold 4 is: 0.5941655436648354
# The score is 0.5942438124383298
# |  6        |  0.5942   |  0.8404   |  9.997    |  0.5123   |  5.95     |  5.839    |  0.03126  |  11.53    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.849629	valid_1's rmse: 0.99755
# [200]	training's rmse: 0.763219	valid_1's rmse: 1.00227
# Early stopping, best iteration is:
# [71]	training's rmse: 0.883158	valid_1's rmse: 0.996606
# Partial score of fold 0 is: 0.5757464431216828
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.853056	valid_1's rmse: 0.986525
# [200]	training's rmse: 0.766249	valid_1's rmse: 0.9904
# Early stopping, best iteration is:
# [109]	training's rmse: 0.843857	valid_1's rmse: 0.985637
# Partial score of fold 1 is: 0.5914926738282588
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.854607	valid_1's rmse: 0.990071
# [200]	training's rmse: 0.76636	valid_1's rmse: 0.98953
# [300]	training's rmse: 0.701907	valid_1's rmse: 0.993757
# Early stopping, best iteration is:
# [152]	training's rmse: 0.804892	valid_1's rmse: 0.987973
# Partial score of fold 2 is: 0.5936398871064282
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.854614	valid_1's rmse: 0.972686
# [200]	training's rmse: 0.771444	valid_1's rmse: 0.972756
# Early stopping, best iteration is:
# [126]	training's rmse: 0.828796	valid_1's rmse: 0.971214
# Partial score of fold 3 is: 0.6022287402191061
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.851916	valid_1's rmse: 0.983816
# [200]	training's rmse: 0.767893	valid_1's rmse: 0.985605
# Early stopping, best iteration is:
# [116]	training's rmse: 0.834927	valid_1's rmse: 0.983564
# Partial score of fold 4 is: 0.5945235012889458
# The score is 0.5915953200788375
# |  7        |  0.5916   |  0.8771   |  9.775    |  0.5826   |  0.2106   |  5.994    |  0.07856  |  11.9     |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.861224	valid_1's rmse: 0.99975
# [200]	training's rmse: 0.784757	valid_1's rmse: 1.00201
# Early stopping, best iteration is:
# [72]	training's rmse: 0.891614	valid_1's rmse: 0.998234
# Partial score of fold 0 is: 0.5719888198848861
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.86608	valid_1's rmse: 0.987006
# [200]	training's rmse: 0.787981	valid_1's rmse: 0.986547
# [300]	training's rmse: 0.731454	valid_1's rmse: 0.990386
# Early stopping, best iteration is:
# [158]	training's rmse: 0.817248	valid_1's rmse: 0.984463
# Partial score of fold 1 is: 0.6009761991401739
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.871078	valid_1's rmse: 0.990837
# [200]	training's rmse: 0.790475	valid_1's rmse: 0.9872
# [300]	training's rmse: 0.731454	valid_1's rmse: 0.991121
# Early stopping, best iteration is:
# [151]	training's rmse: 0.825065	valid_1's rmse: 0.985775
# Partial score of fold 2 is: 0.5929241493470384
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.866926	valid_1's rmse: 0.975008
# [200]	training's rmse: 0.790262	valid_1's rmse: 0.974375
# [300]	training's rmse: 0.733644	valid_1's rmse: 0.97611
# Early stopping, best iteration is:
# [209]	training's rmse: 0.784349	valid_1's rmse: 0.973491
# Partial score of fold 3 is: 0.5993657891815468
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.865405	valid_1's rmse: 0.984193
# [200]	training's rmse: 0.788125	valid_1's rmse: 0.985099
# Early stopping, best iteration is:
# [118]	training's rmse: 0.848704	valid_1's rmse: 0.98358
# Partial score of fold 4 is: 0.594702480101001
# The score is 0.5918100627025802
# |  8        |  0.5918   |  0.8337   |  9.82     |  0.4103   |  5.857    |  5.642    |  0.08312  |  11.92    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.935719	valid_1's rmse: 1.00425
# [200]	training's rmse: 0.879616	valid_1's rmse: 0.99883
# [300]	training's rmse: 0.842511	valid_1's rmse: 1.00047
# Early stopping, best iteration is:
# [218]	training's rmse: 0.872225	valid_1's rmse: 0.997655
# Partial score of fold 0 is: 0.5746728364825979
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.943472	valid_1's rmse: 1.00368
# [200]	training's rmse: 0.883948	valid_1's rmse: 0.987836
# [300]	training's rmse: 0.846141	valid_1's rmse: 0.987303
# [400]	training's rmse: 0.815059	valid_1's rmse: 0.989203
# Early stopping, best iteration is:
# [307]	training's rmse: 0.843783	valid_1's rmse: 0.986721
# Partial score of fold 1 is: 0.5936398871064282
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.948322	valid_1's rmse: 1.00665
# [200]	training's rmse: 0.884414	valid_1's rmse: 0.985924
# [300]	training's rmse: 0.846195	valid_1's rmse: 0.984482
# [400]	training's rmse: 0.814608	valid_1's rmse: 0.985682
# Early stopping, best iteration is:
# [269]	training's rmse: 0.856744	valid_1's rmse: 0.984225
# Partial score of fold 2 is: 0.6027655435386485
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.942823	valid_1's rmse: 0.989696
# [200]	training's rmse: 0.887519	valid_1's rmse: 0.975006
# [300]	training's rmse: 0.850449	valid_1's rmse: 0.969979
# [400]	training's rmse: 0.81938	valid_1's rmse: 0.971307
# Early stopping, best iteration is:
# [288]	training's rmse: 0.854465	valid_1's rmse: 0.969458
# Partial score of fold 3 is: 0.598650051422157
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.939844	valid_1's rmse: 0.996864
# [200]	training's rmse: 0.883945	valid_1's rmse: 0.985636
# [300]	training's rmse: 0.846359	valid_1's rmse: 0.985578
# [400]	training's rmse: 0.815872	valid_1's rmse: 0.986696
# Early stopping, best iteration is:
# [288]	training's rmse: 0.850424	valid_1's rmse: 0.984788
# Partial score of fold 4 is: 0.5916598402960627
# The score is 0.5920605957636133
# |  9        |  0.5921   |  0.5586   |  9.95     |  0.4965   |  5.894    |  5.392    |  0.0361   |  8.112    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.861174	valid_1's rmse: 0.997363
# [200]	training's rmse: 0.782843	valid_1's rmse: 1.00324
# Early stopping, best iteration is:
# [98]	training's rmse: 0.863044	valid_1's rmse: 0.996857
# Partial score of fold 0 is: 0.572704557644276
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.864063	valid_1's rmse: 0.989632
# [200]	training's rmse: 0.786102	valid_1's rmse: 0.991723
# Early stopping, best iteration is:
# [112]	training's rmse: 0.852973	valid_1's rmse: 0.988694
# Partial score of fold 1 is: 0.5916716082681062
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.870794	valid_1's rmse: 0.988557
# [200]	training's rmse: 0.788375	valid_1's rmse: 0.989286
# Early stopping, best iteration is:
# [140]	training's rmse: 0.832823	valid_1's rmse: 0.984449
# Partial score of fold 2 is: 0.6050916912566654
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.866473	valid_1's rmse: 0.973381
# [200]	training's rmse: 0.789292	valid_1's rmse: 0.974623
# Early stopping, best iteration is:
# [124]	training's rmse: 0.844926	valid_1's rmse: 0.971382
# Partial score of fold 3 is: 0.6011551335800214
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.865016	valid_1's rmse: 0.985763
# [200]	training's rmse: 0.78635	valid_1's rmse: 0.986974
# Early stopping, best iteration is:
# [123]	training's rmse: 0.844002	valid_1's rmse: 0.983787
# Partial score of fold 4 is: 0.5889751581152347
# The score is 0.5927048236348411
# |  10       |  0.5927   |  0.7591   |  9.748    |  0.4699   |  5.957    |  0.02445  |  0.08031  |  11.86    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.908182	valid_1's rmse: 0.998899
# [200]	training's rmse: 0.84804	valid_1's rmse: 1.00419
# Early stopping, best iteration is:
# [111]	training's rmse: 0.900426	valid_1's rmse: 0.997576
# Partial score of fold 0 is: 0.5793251319186319
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.911279	valid_1's rmse: 0.993398
# [200]	training's rmse: 0.849384	valid_1's rmse: 0.988508
# [300]	training's rmse: 0.806088	valid_1's rmse: 0.990214
# Early stopping, best iteration is:
# [249]	training's rmse: 0.827411	valid_1's rmse: 0.988036
# Partial score of fold 1 is: 0.5959660348244451
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.916241	valid_1's rmse: 0.996527
# [200]	training's rmse: 0.852699	valid_1's rmse: 0.987998
# [300]	training's rmse: 0.807687	valid_1's rmse: 0.99142
# Early stopping, best iteration is:
# [191]	training's rmse: 0.857351	valid_1's rmse: 0.986569
# Partial score of fold 2 is: 0.5982921825424621
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.916246	valid_1's rmse: 0.978598
# [200]	training's rmse: 0.856807	valid_1's rmse: 0.976782
# [300]	training's rmse: 0.812163	valid_1's rmse: 0.976279
# [400]	training's rmse: 0.774973	valid_1's rmse: 0.975388
# [500]	training's rmse: 0.742906	valid_1's rmse: 0.979666
# Early stopping, best iteration is:
# [385]	training's rmse: 0.780144	valid_1's rmse: 0.974631
# Partial score of fold 3 is: 0.5932820182267333
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.911365	valid_1's rmse: 0.988111
# [200]	training's rmse: 0.85061	valid_1's rmse: 0.986111
# Early stopping, best iteration is:
# [123]	training's rmse: 0.894579	valid_1's rmse: 0.985488
# Partial score of fold 4 is: 0.5909439250478419
# The score is 0.5914163678923854
# |  11       |  0.5914   |  0.4575   |  9.882    |  0.5087   |  5.765    |  5.915    |  0.05408  |  11.89    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.941436	valid_1's rmse: 1.01194
# [200]	training's rmse: 0.877021	valid_1's rmse: 0.999622
# [300]	training's rmse: 0.836603	valid_1's rmse: 0.998789
# [400]	training's rmse: 0.80385	valid_1's rmse: 1.00076
# Early stopping, best iteration is:
# [278]	training's rmse: 0.844911	valid_1's rmse: 0.998321
# Partial score of fold 0 is: 0.5701994754864116
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.942121	valid_1's rmse: 1.00212
# [200]	training's rmse: 0.878378	valid_1's rmse: 0.988296
# [300]	training's rmse: 0.837554	valid_1's rmse: 0.986672
# [400]	training's rmse: 0.803316	valid_1's rmse: 0.987483
# Early stopping, best iteration is:
# [305]	training's rmse: 0.835598	valid_1's rmse: 0.986357
# Partial score of fold 1 is: 0.592745214907191
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.949633	valid_1's rmse: 1.00718
# [200]	training's rmse: 0.881893	valid_1's rmse: 0.986633
# [300]	training's rmse: 0.839056	valid_1's rmse: 0.98472
# [400]	training's rmse: 0.805517	valid_1's rmse: 0.985358
# [500]	training's rmse: 0.775003	valid_1's rmse: 0.986026
# Early stopping, best iteration is:
# [353]	training's rmse: 0.821029	valid_1's rmse: 0.984437
# Partial score of fold 2 is: 0.5977553792229198
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.946174	valid_1's rmse: 0.993051
# [200]	training's rmse: 0.881923	valid_1's rmse: 0.974253
# [300]	training's rmse: 0.841615	valid_1's rmse: 0.970622
# [400]	training's rmse: 0.807161	valid_1's rmse: 0.969426
# [500]	training's rmse: 0.777153	valid_1's rmse: 0.969936
# Early stopping, best iteration is:
# [419]	training's rmse: 0.800837	valid_1's rmse: 0.969096
# Partial score of fold 3 is: 0.6018708713394112
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.943835	valid_1's rmse: 0.999899
# [200]	training's rmse: 0.880638	valid_1's rmse: 0.982899
# [300]	training's rmse: 0.839367	valid_1's rmse: 0.981072
# [400]	training's rmse: 0.804482	valid_1's rmse: 0.981121
# [500]	training's rmse: 0.776884	valid_1's rmse: 0.982512
# Early stopping, best iteration is:
# [377]	training's rmse: 0.812482	valid_1's rmse: 0.980718
# Partial score of fold 4 is: 0.5923757555442835
# The score is 0.5909510922076098
# |  12       |  0.591    |  0.8186   |  9.987    |  0.5857   |  0.01323  |  0.0651   |  0.0277   |  8.063    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.957635	valid_1's rmse: 1.01826
# [200]	training's rmse: 0.895744	valid_1's rmse: 0.999762
# [300]	training's rmse: 0.857635	valid_1's rmse: 0.99681
# [400]	training's rmse: 0.826251	valid_1's rmse: 0.997037
# Early stopping, best iteration is:
# [293]	training's rmse: 0.859937	valid_1's rmse: 0.996719
# Partial score of fold 0 is: 0.568410131087937
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.966073	valid_1's rmse: 1.01553
# [200]	training's rmse: 0.898689	valid_1's rmse: 0.989526
# [300]	training's rmse: 0.859078	valid_1's rmse: 0.984327
# [400]	training's rmse: 0.828463	valid_1's rmse: 0.983928
# [500]	training's rmse: 0.801346	valid_1's rmse: 0.98488
# Early stopping, best iteration is:
# [361]	training's rmse: 0.839339	valid_1's rmse: 0.983366
# Partial score of fold 1 is: 0.5952502970650553
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.980632	valid_1's rmse: 1.03197
# [200]	training's rmse: 0.901588	valid_1's rmse: 0.990231
# [300]	training's rmse: 0.862089	valid_1's rmse: 0.984019
# [400]	training's rmse: 0.830565	valid_1's rmse: 0.982705
# [500]	training's rmse: 0.803755	valid_1's rmse: 0.982661
# Early stopping, best iteration is:
# [414]	training's rmse: 0.82633	valid_1's rmse: 0.982323
# Partial score of fold 2 is: 0.5975764447830723
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.962679	valid_1's rmse: 1.00084
# [200]	training's rmse: 0.902271	valid_1's rmse: 0.977762
# [300]	training's rmse: 0.864196	valid_1's rmse: 0.971555
# [400]	training's rmse: 0.833702	valid_1's rmse: 0.969218
# [500]	training's rmse: 0.807164	valid_1's rmse: 0.968128
# [600]	training's rmse: 0.782732	valid_1's rmse: 0.968114
# [700]	training's rmse: 0.761663	valid_1's rmse: 0.967716
# [800]	training's rmse: 0.742023	valid_1's rmse: 0.968074
# Early stopping, best iteration is:
# [667]	training's rmse: 0.768365	valid_1's rmse: 0.967478
# Partial score of fold 3 is: 0.606523166775445
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.959646	valid_1's rmse: 1.00868
# [200]	training's rmse: 0.898484	valid_1's rmse: 0.987238
# [300]	training's rmse: 0.860272	valid_1's rmse: 0.982058
# [400]	training's rmse: 0.829417	valid_1's rmse: 0.979321
# [500]	training's rmse: 0.803159	valid_1's rmse: 0.979734
# Early stopping, best iteration is:
# [417]	training's rmse: 0.824614	valid_1's rmse: 0.979094
# Partial score of fold 4 is: 0.5952394165371666
# The score is 0.5949238307468481
# |  13       |  0.5949   |  0.9411   |  9.877    |  0.4124   |  5.654    |  0.124    |  0.02673  |  11.81    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.933123	valid_1's rmse: 1.00549
# [200]	training's rmse: 0.871834	valid_1's rmse: 0.995442
# [300]	training's rmse: 0.830988	valid_1's rmse: 0.996061
# Early stopping, best iteration is:
# [219]	training's rmse: 0.863156	valid_1's rmse: 0.995158
# Partial score of fold 0 is: 0.5735992298435133
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.935415	valid_1's rmse: 0.999605
# [200]	training's rmse: 0.873872	valid_1's rmse: 0.985745
# [300]	training's rmse: 0.83286	valid_1's rmse: 0.984258
# [400]	training's rmse: 0.799191	valid_1's rmse: 0.985745
# Early stopping, best iteration is:
# [269]	training's rmse: 0.843966	valid_1's rmse: 0.983653
# Partial score of fold 1 is: 0.5975764447830723
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.942989	valid_1's rmse: 1.00381
# [200]	training's rmse: 0.877349	valid_1's rmse: 0.984283
# [300]	training's rmse: 0.834955	valid_1's rmse: 0.982148
# [400]	training's rmse: 0.801128	valid_1's rmse: 0.982662
# Early stopping, best iteration is:
# [324]	training's rmse: 0.826108	valid_1's rmse: 0.981876
# Partial score of fold 2 is: 0.6007972647003265
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.93814	valid_1's rmse: 0.986548
# [200]	training's rmse: 0.878275	valid_1's rmse: 0.969517
# [300]	training's rmse: 0.838169	valid_1's rmse: 0.968172
# [400]	training's rmse: 0.803903	valid_1's rmse: 0.967686
# [500]	training's rmse: 0.774413	valid_1's rmse: 0.967363
# Early stopping, best iteration is:
# [448]	training's rmse: 0.789217	valid_1's rmse: 0.966811
# Partial score of fold 3 is: 0.6041970190574282
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.93522	valid_1's rmse: 0.99536
# [200]	training's rmse: 0.874963	valid_1's rmse: 0.982302
# [300]	training's rmse: 0.834113	valid_1's rmse: 0.981654
# [400]	training's rmse: 0.80031	valid_1's rmse: 0.982644
# Early stopping, best iteration is:
# [270]	training's rmse: 0.845529	valid_1's rmse: 0.980829
# Partial score of fold 4 is: 0.5918388191081179
# The score is 0.5946375072485246
# |  14       |  0.5946   |  0.7998   |  9.93     |  0.5294   |  5.934    |  0.2458   |  0.03401  |  11.8     |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.861707	valid_1's rmse: 1.00359
# [200]	training's rmse: 0.78728	valid_1's rmse: 1.01432
# Early stopping, best iteration is:
# [85]	training's rmse: 0.876167	valid_1's rmse: 1.00265
# Partial score of fold 0 is: 0.5737781642833607
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.866966	valid_1's rmse: 0.99564
# [200]	training's rmse: 0.79113	valid_1's rmse: 0.999233
# Early stopping, best iteration is:
# [109]	training's rmse: 0.858685	valid_1's rmse: 0.994085
# Partial score of fold 1 is: 0.5852299684335979
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.868065	valid_1's rmse: 0.995695
# [200]	training's rmse: 0.79161	valid_1's rmse: 1.00026
# Early stopping, best iteration is:
# [122]	training's rmse: 0.847576	valid_1's rmse: 0.99419
# Partial score of fold 2 is: 0.5884507883508521
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.869612	valid_1's rmse: 0.982419
# [200]	training's rmse: 0.795425	valid_1's rmse: 0.986873
# Early stopping, best iteration is:
# [67]	training's rmse: 0.903631	valid_1's rmse: 0.981235
# Partial score of fold 3 is: 0.5888086572305469
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.866688	valid_1's rmse: 0.992191
# [200]	training's rmse: 0.789873	valid_1's rmse: 0.997682
# Early stopping, best iteration is:
# [112]	training's rmse: 0.855124	valid_1's rmse: 0.991794
# Partial score of fold 4 is: 0.5871853699946827
# The score is 0.5839003760613939
# |  15       |  0.5839   |  0.448    |  9.532    |  0.4481   |  5.86     |  0.002919 |  0.09353  |  11.79    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.902058	valid_1's rmse: 0.998745
# [200]	training's rmse: 0.838782	valid_1's rmse: 0.997358
# [300]	training's rmse: 0.792726	valid_1's rmse: 0.9995
# Early stopping, best iteration is:
# [163]	training's rmse: 0.859044	valid_1's rmse: 0.996358
# Partial score of fold 0 is: 0.5746728364825979
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.905043	valid_1's rmse: 0.990289
# [200]	training's rmse: 0.840905	valid_1's rmse: 0.985357
# [300]	training's rmse: 0.79446	valid_1's rmse: 0.985301
# [400]	training's rmse: 0.755951	valid_1's rmse: 0.986183
# Early stopping, best iteration is:
# [255]	training's rmse: 0.813853	valid_1's rmse: 0.984751
# Partial score of fold 1 is: 0.5956081659447503
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.909809	valid_1's rmse: 0.989777
# [200]	training's rmse: 0.843196	valid_1's rmse: 0.983814
# [300]	training's rmse: 0.797875	valid_1's rmse: 0.9852
# Early stopping, best iteration is:
# [193]	training's rmse: 0.846949	valid_1's rmse: 0.98352
# Partial score of fold 2 is: 0.5975764447830723
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.908062	valid_1's rmse: 0.974535
# [200]	training's rmse: 0.844815	valid_1's rmse: 0.968325
# [300]	training's rmse: 0.798655	valid_1's rmse: 0.968243
# [400]	training's rmse: 0.760622	valid_1's rmse: 0.969356
# Early stopping, best iteration is:
# [251]	training's rmse: 0.820227	valid_1's rmse: 0.967523
# Partial score of fold 3 is: 0.6052706256965128
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.903825	valid_1's rmse: 0.986369
# [200]	training's rmse: 0.840626	valid_1's rmse: 0.98289
# [300]	training's rmse: 0.794574	valid_1's rmse: 0.984818
# Early stopping, best iteration is:
# [195]	training's rmse: 0.843191	valid_1's rmse: 0.982824
# Partial score of fold 4 is: 0.5954634153498539
# The score is 0.5943153933129106
# |  16       |  0.5943   |  0.9968   |  9.965    |  0.571    |  5.877    |  5.287    |  0.04893  |  11.08    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.958869	valid_1's rmse: 1.01572
# [200]	training's rmse: 0.89927	valid_1's rmse: 0.997321
# [300]	training's rmse: 0.864501	valid_1's rmse: 0.995313
# [400]	training's rmse: 0.835566	valid_1's rmse: 0.996012
# Early stopping, best iteration is:
# [325]	training's rmse: 0.856707	valid_1's rmse: 0.99498
# Partial score of fold 0 is: 0.575030705362293
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.959772	valid_1's rmse: 1.00744
# [200]	training's rmse: 0.899968	valid_1's rmse: 0.987537
# [300]	training's rmse: 0.865639	valid_1's rmse: 0.983868
# [400]	training's rmse: 0.838135	valid_1's rmse: 0.983353
# [500]	training's rmse: 0.813944	valid_1's rmse: 0.983346
# Early stopping, best iteration is:
# [415]	training's rmse: 0.834638	valid_1's rmse: 0.983089
# Partial score of fold 1 is: 0.5952502970650553
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.967498	valid_1's rmse: 1.01332
# [200]	training's rmse: 0.904823	valid_1's rmse: 0.985792
# [300]	training's rmse: 0.868808	valid_1's rmse: 0.981057
# [400]	training's rmse: 0.840262	valid_1's rmse: 0.980694
# [500]	training's rmse: 0.815444	valid_1's rmse: 0.981162
# Early stopping, best iteration is:
# [362]	training's rmse: 0.850299	valid_1's rmse: 0.980415
# Partial score of fold 2 is: 0.6015130024597163
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.963674	valid_1's rmse: 0.997382
# [200]	training's rmse: 0.904672	valid_1's rmse: 0.973129
# [300]	training's rmse: 0.869464	valid_1's rmse: 0.967201
# [400]	training's rmse: 0.841382	valid_1's rmse: 0.965818
# [500]	training's rmse: 0.816564	valid_1's rmse: 0.965424
# [600]	training's rmse: 0.794171	valid_1's rmse: 0.965501
# Early stopping, best iteration is:
# [495]	training's rmse: 0.817582	valid_1's rmse: 0.965232
# Partial score of fold 3 is: 0.6072389045348349
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.96161	valid_1's rmse: 1.00704
# [200]	training's rmse: 0.901863	valid_1's rmse: 0.982962
# [300]	training's rmse: 0.86681	valid_1's rmse: 0.980082
# [400]	training's rmse: 0.837892	valid_1's rmse: 0.979565
# [500]	training's rmse: 0.813427	valid_1's rmse: 0.980834
# Early stopping, best iteration is:
# [400]	training's rmse: 0.837892	valid_1's rmse: 0.979565
# Partial score of fold 4 is: 0.5916598402960627
# The score is 0.5942796028756203
# |  17       |  0.5943   |  0.9977   |  9.817    |  0.5705   |  5.353    |  5.915    |  0.02547  |  8.391    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.937292	valid_1's rmse: 1.00796
# [200]	training's rmse: 0.878144	valid_1's rmse: 0.998068
# [300]	training's rmse: 0.83875	valid_1's rmse: 0.997692
# Early stopping, best iteration is:
# [243]	training's rmse: 0.859975	valid_1's rmse: 0.997454
# Partial score of fold 0 is: 0.572601537048318
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.940489	valid_1's rmse: 0.999235
# [200]	training's rmse: 0.879578	valid_1's rmse: 0.985668
# [300]	training's rmse: 0.839742	valid_1's rmse: 0.983555
# [400]	training's rmse: 0.80776	valid_1's rmse: 0.983776
# Early stopping, best iteration is:
# [299]	training's rmse: 0.84012	valid_1's rmse: 0.983443
# Partial score of fold 1 is: 0.5988289858620044
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.947823	valid_1's rmse: 1.00471
# [200]	training's rmse: 0.883377	valid_1's rmse: 0.983895
# [300]	training's rmse: 0.842585	valid_1's rmse: 0.980772
# [400]	training's rmse: 0.809212	valid_1's rmse: 0.980759
# [500]	training's rmse: 0.781353	valid_1's rmse: 0.981856
# Early stopping, best iteration is:
# [354]	training's rmse: 0.824339	valid_1's rmse: 0.980376
# Partial score of fold 2 is: 0.6011551335800214
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.943885	valid_1's rmse: 0.988429
# [200]	training's rmse: 0.884844	valid_1's rmse: 0.970841
# [300]	training's rmse: 0.845725	valid_1's rmse: 0.967811
# [400]	training's rmse: 0.813739	valid_1's rmse: 0.967267
# [500]	training's rmse: 0.786015	valid_1's rmse: 0.967193
# [600]	training's rmse: 0.761363	valid_1's rmse: 0.967537
# Early stopping, best iteration is:
# [493]	training's rmse: 0.787605	valid_1's rmse: 0.967076
# Partial score of fold 3 is: 0.6041970190574282
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.940659	valid_1's rmse: 0.996856
# [200]	training's rmse: 0.882267	valid_1's rmse: 0.981748
# [300]	training's rmse: 0.842606	valid_1's rmse: 0.98065
# Early stopping, best iteration is:
# [239]	training's rmse: 0.865559	valid_1's rmse: 0.980176
# Partial score of fold 4 is: 0.5934496284166146
# The score is 0.5941364411264585
# |  18       |  0.5941   |  0.9839   |  9.32     |  0.5265   |  5.701    |  5.646    |  0.03265  |  11.84    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.93457	valid_1's rmse: 1.00483
# [200]	training's rmse: 0.875784	valid_1's rmse: 0.995638
# [300]	training's rmse: 0.835586	valid_1's rmse: 0.996482
# [400]	training's rmse: 0.803431	valid_1's rmse: 0.997641
# Early stopping, best iteration is:
# [257]	training's rmse: 0.851645	valid_1's rmse: 0.995399
# Partial score of fold 0 is: 0.5719795107334282
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.936665	valid_1's rmse: 0.995721
# [200]	training's rmse: 0.877331	valid_1's rmse: 0.984423
# [300]	training's rmse: 0.837822	valid_1's rmse: 0.9838
# [400]	training's rmse: 0.805384	valid_1's rmse: 0.983546
# [500]	training's rmse: 0.777396	valid_1's rmse: 0.984081
# Early stopping, best iteration is:
# [364]	training's rmse: 0.816347	valid_1's rmse: 0.982777
# Partial score of fold 1 is: 0.5972185759033773
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.941911	valid_1's rmse: 1.0002
# [200]	training's rmse: 0.880018	valid_1's rmse: 0.982477
# [300]	training's rmse: 0.839933	valid_1's rmse: 0.979531
# [400]	training's rmse: 0.807245	valid_1's rmse: 0.979327
# [500]	training's rmse: 0.778245	valid_1's rmse: 0.979955
# Early stopping, best iteration is:
# [375]	training's rmse: 0.814653	valid_1's rmse: 0.97884
# Partial score of fold 2 is: 0.6029444779784959
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.940745	valid_1's rmse: 0.985421
# [200]	training's rmse: 0.881831	valid_1's rmse: 0.969641
# [300]	training's rmse: 0.843088	valid_1's rmse: 0.967087
# [400]	training's rmse: 0.809813	valid_1's rmse: 0.966457
# [500]	training's rmse: 0.781206	valid_1's rmse: 0.966358
# Early stopping, best iteration is:
# [428]	training's rmse: 0.80143	valid_1's rmse: 0.96627
# Partial score of fold 3 is: 0.6059863634559026
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.936874	valid_1's rmse: 0.993844
# [200]	training's rmse: 0.878502	valid_1's rmse: 0.980872
# [300]	training's rmse: 0.839183	valid_1's rmse: 0.980069
# [400]	training's rmse: 0.806612	valid_1's rmse: 0.981076
# Early stopping, best iteration is:
# [282]	training's rmse: 0.845539	valid_1's rmse: 0.979967
# Partial score of fold 4 is: 0.5968502258456634
# The score is 0.5946375072485246
# |  19       |  0.5946   |  0.9943   |  9.935    |  0.5644   |  5.401    |  5.644    |  0.0331   |  11.57    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.938128	valid_1's rmse: 1.00729
# [200]	training's rmse: 0.879837	valid_1's rmse: 0.996859
# [300]	training's rmse: 0.840816	valid_1's rmse: 0.996601
# [400]	training's rmse: 0.810047	valid_1's rmse: 0.997953
# Early stopping, best iteration is:
# [276]	training's rmse: 0.849446	valid_1's rmse: 0.996122
# Partial score of fold 0 is: 0.5678733277683947
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.94121	valid_1's rmse: 0.999268
# [200]	training's rmse: 0.881572	valid_1's rmse: 0.986964
# [300]	training's rmse: 0.843191	valid_1's rmse: 0.98518
# [400]	training's rmse: 0.812333	valid_1's rmse: 0.984999
# [500]	training's rmse: 0.784944	valid_1's rmse: 0.985197
# Early stopping, best iteration is:
# [379]	training's rmse: 0.817822	valid_1's rmse: 0.984649
# Partial score of fold 1 is: 0.5932820182267333
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.947057	valid_1's rmse: 1.00346
# [200]	training's rmse: 0.883992	valid_1's rmse: 0.982747
# [300]	training's rmse: 0.84437	valid_1's rmse: 0.980296
# [400]	training's rmse: 0.813088	valid_1's rmse: 0.980937
# Early stopping, best iteration is:
# [334]	training's rmse: 0.832697	valid_1's rmse: 0.979897
# Partial score of fold 2 is: 0.5999025925010892
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.943977	valid_1's rmse: 0.986197
# [200]	training's rmse: 0.886124	valid_1's rmse: 0.969518
# [300]	training's rmse: 0.847324	valid_1's rmse: 0.965896
# [400]	training's rmse: 0.816758	valid_1's rmse: 0.964854
# [500]	training's rmse: 0.788433	valid_1's rmse: 0.964519
# [600]	training's rmse: 0.763691	valid_1's rmse: 0.965546
# Early stopping, best iteration is:
# [496]	training's rmse: 0.789384	valid_1's rmse: 0.964407
# Partial score of fold 3 is: 0.6101018555723942
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.940963	valid_1's rmse: 0.996771
# [200]	training's rmse: 0.883	valid_1's rmse: 0.981873
# [300]	training's rmse: 0.844041	valid_1's rmse: 0.980995
# [400]	training's rmse: 0.812984	valid_1's rmse: 0.982186
# Early stopping, best iteration is:
# [278]	training's rmse: 0.852041	valid_1's rmse: 0.980899
# Partial score of fold 4 is: 0.5893331157393451
# The score is 0.5927764045094219
# |  20       |  0.5928   |  0.9961   |  9.478    |  0.5454   |  5.999    |  5.844    |  0.03225  |  11.78    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.860114	valid_1's rmse: 0.996228
# [200]	training's rmse: 0.78468	valid_1's rmse: 1.00133
# Early stopping, best iteration is:
# [96]	training's rmse: 0.86405	valid_1's rmse: 0.996047
# Partial score of fold 0 is: 0.5748517709224454
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.861923	valid_1's rmse: 0.9861
# [200]	training's rmse: 0.785362	valid_1's rmse: 0.989147
# Early stopping, best iteration is:
# [110]	training's rmse: 0.852634	valid_1's rmse: 0.986073
# Partial score of fold 1 is: 0.5932820182267333
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.864919	valid_1's rmse: 0.985618
# [200]	training's rmse: 0.787414	valid_1's rmse: 0.984351
# [300]	training's rmse: 0.728203	valid_1's rmse: 0.98784
# Early stopping, best iteration is:
# [160]	training's rmse: 0.815296	valid_1's rmse: 0.984046
# Partial score of fold 2 is: 0.5932820182267333
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.866181	valid_1's rmse: 0.969966
# [200]	training's rmse: 0.789677	valid_1's rmse: 0.968756
# [300]	training's rmse: 0.732573	valid_1's rmse: 0.970512
# Early stopping, best iteration is:
# [230]	training's rmse: 0.771259	valid_1's rmse: 0.968263
# Partial score of fold 3 is: 0.604554887937123
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.860788	valid_1's rmse: 0.984523
# [200]	training's rmse: 0.784831	valid_1's rmse: 0.987244
# Early stopping, best iteration is:
# [93]	training's rmse: 0.867409	valid_1's rmse: 0.984334
# Partial score of fold 4 is: 0.5921517658051259
# The score is 0.5911300443940619
# |  21       |  0.5911   |  0.9946   |  9.891    |  0.5774   |  5.826    |  5.58     |  0.08146  |  8.303    |
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.892011	valid_1's rmse: 0.997314
# [200]	training's rmse: 0.822291	valid_1's rmse: 0.995906
# Early stopping, best iteration is:
# [148]	training's rmse: 0.854847	valid_1's rmse: 0.995521
# Partial score of fold 0 is: 0.5710941476856488
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.897302	valid_1's rmse: 0.991971
# [200]	training's rmse: 0.824581	valid_1's rmse: 0.986515
# [300]	training's rmse: 0.771357	valid_1's rmse: 0.98609
# [400]	training's rmse: 0.726899	valid_1's rmse: 0.988496
# Early stopping, best iteration is:
# [268]	training's rmse: 0.787212	valid_1's rmse: 0.985092
# Partial score of fold 1 is: 0.590419067189174
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.906884	valid_1's rmse: 0.997053
# [200]	training's rmse: 0.825763	valid_1's rmse: 0.982641
# [300]	training's rmse: 0.773254	valid_1's rmse: 0.982444
# [400]	training's rmse: 0.72947	valid_1's rmse: 0.984417
# Early stopping, best iteration is:
# [258]	training's rmse: 0.79345	valid_1's rmse: 0.981394
# Partial score of fold 2 is: 0.5984711169823096
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.898542	valid_1's rmse: 0.976268
# [200]	training's rmse: 0.829145	valid_1's rmse: 0.970003
# [300]	training's rmse: 0.777443	valid_1's rmse: 0.970166
# Early stopping, best iteration is:
# [229]	training's rmse: 0.812602	valid_1's rmse: 0.969569
# Partial score of fold 3 is: 0.5990079203018519
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.896317	valid_1's rmse: 0.98659
# [200]	training's rmse: 0.824912	valid_1's rmse: 0.982585
# Early stopping, best iteration is:
# [145]	training's rmse: 0.860029	valid_1's rmse: 0.981934
# Partial score of fold 4 is: 0.5904069886116763
# The score is 0.5907721400211575
# |  22       |  0.5908   |  0.9998   |  9.875    |  0.4116   |  0.9975   |  4.33     |  0.0512   |  11.84    |
# =============================================================================================================
#
#  Time taken: 0 hours 12 minutes and 43.3 seconds.

# %%
print('-'*130)
print('Final Results')
print('Maximum  value: %f' % LGB_BO.max['target'])
print('Best  parameters:', LGB_BO.max['params'])

if LGB_BO.max['target'] > 0.596892:
    LGB_pramas = LGB_BO.max['params']
else:
    LGB_pramas = {
    'bagging_fraction': 0.5703482080116283, 
    'bagging_freq': 1.1066058349920214,
    'colsample_bytree': 0.5515000831403941,
    'lambda_l1': 5.8079230594147,
    'lambda_l2': 5.988476114292218, 
    'learning_rate': 0.02606739709720534,
    'max_depth': 8.184768586407403}

# Maximum  value: 0.596892
# Best  parameters: {
#     'bagging_fraction': 0.5703482080116283, 
#     'bagging_freq': 1.1066058349920214,
#     'colsample_bytree': 0.5515000831403941,
#     'lambda_l1': 5.8079230594147,
#     'lambda_l2': 5.988476114292218, 
#     'learning_rate': 0.02606739709720534,
#     'max_depth': 8.184768586407403}
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------
# Final Results
# Maximum  value: 0.596821
# Best  parameters: {'bagging_fraction': 0.9916249742183844, 'bagging_freq': 9.882303927272844, 'colsample_bytree': 0.5016736877019821, 'lambda_l1': 0.17613411337038842, 'lambda_l2': 5.855637930336883, 'learning_rate': 0.0454186165192345, 'max_depth': 11.923254063852392}

# %%
reduce_train.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in reduce_train.columns]
ajusted_test.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in ajusted_test.columns]
features = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in features]


#cat_model = Catb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
lgb_model = Lgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
xgb_model = Xgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# Out:
# Found `n_estimators` in params. Will use it instead of argument
# Found `early_stopping_rounds` in params. Will use it instead of argument
# Using categorical_feature in Dataset.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.02956	valid_1's rmse: 1.05827
# [200]	training's rmse: 0.961864	valid_1's rmse: 1.01516
# [300]	training's rmse: 0.926809	valid_1's rmse: 1.00141
# [400]	training's rmse: 0.902377	valid_1's rmse: 0.995675
# [500]	training's rmse: 0.882486	valid_1's rmse: 0.99237
# [600]	training's rmse: 0.864902	valid_1's rmse: 0.990461
# [700]	training's rmse: 0.849175	valid_1's rmse: 0.98952
# [800]	training's rmse: 0.834419	valid_1's rmse: 0.988881
# [900]	training's rmse: 0.82066	valid_1's rmse: 0.988721
# Early stopping, best iteration is:
# [868]	training's rmse: 0.825009	valid_1's rmse: 0.988535
# Partial score of fold 0 is: 0.5802198041178691
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.03421	valid_1's rmse: 1.05088
# [200]	training's rmse: 0.96545	valid_1's rmse: 1.00269
# [300]	training's rmse: 0.929877	valid_1's rmse: 0.986751
# [400]	training's rmse: 0.905566	valid_1's rmse: 0.98138
# [500]	training's rmse: 0.88595	valid_1's rmse: 0.979431
# [600]	training's rmse: 0.86851	valid_1's rmse: 0.978528
# [700]	training's rmse: 0.85264	valid_1's rmse: 0.978027
# [800]	training's rmse: 0.8383	valid_1's rmse: 0.977758
# Early stopping, best iteration is:
# [796]	training's rmse: 0.838864	valid_1's rmse: 0.977707
# Partial score of fold 1 is: 0.5993657891815468
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.03235	valid_1's rmse: 1.05905
# [200]	training's rmse: 0.96352	valid_1's rmse: 1.01197
# [300]	training's rmse: 0.928226	valid_1's rmse: 0.996314
# [400]	training's rmse: 0.903576	valid_1's rmse: 0.989047
# [500]	training's rmse: 0.883767	valid_1's rmse: 0.985711
# [600]	training's rmse: 0.866476	valid_1's rmse: 0.983612
# [700]	training's rmse: 0.85081	valid_1's rmse: 0.982569
# [800]	training's rmse: 0.836327	valid_1's rmse: 0.98215
# [900]	training's rmse: 0.822732	valid_1's rmse: 0.982342
# Early stopping, best iteration is:
# [836]	training's rmse: 0.83137	valid_1's rmse: 0.982065
# Partial score of fold 2 is: 0.5957871003845977
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.0339	valid_1's rmse: 1.05318
# [200]	training's rmse: 0.965787	valid_1's rmse: 1.00436
# [300]	training's rmse: 0.930927	valid_1's rmse: 0.988224
# [400]	training's rmse: 0.90653	valid_1's rmse: 0.982517
# [500]	training's rmse: 0.887011	valid_1's rmse: 0.980359
# [600]	training's rmse: 0.869605	valid_1's rmse: 0.979319
# [700]	training's rmse: 0.853908	valid_1's rmse: 0.978807
# [800]	training's rmse: 0.839187	valid_1's rmse: 0.978795
# Early stopping, best iteration is:
# [729]	training's rmse: 0.84943	valid_1's rmse: 0.978592
# Partial score of fold 3 is: 0.5968607070236824
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.03328	valid_1's rmse: 1.05123
# [200]	training's rmse: 0.965112	valid_1's rmse: 1.0048
# [300]	training's rmse: 0.930405	valid_1's rmse: 0.990345
# [400]	training's rmse: 0.906688	valid_1's rmse: 0.984499
# [500]	training's rmse: 0.886955	valid_1's rmse: 0.981162
# [600]	training's rmse: 0.870294	valid_1's rmse: 0.979703
# [700]	training's rmse: 0.854915	valid_1's rmse: 0.97845
# [800]	training's rmse: 0.840787	valid_1's rmse: 0.977528
# [900]	training's rmse: 0.82718	valid_1's rmse: 0.976841
# [1000]	training's rmse: 0.814332	valid_1's rmse: 0.976685
# [1100]	training's rmse: 0.802135	valid_1's rmse: 0.976554
# Early stopping, best iteration is:
# [1087]	training's rmse: 0.803684	valid_1's rmse: 0.976443
# Partial score of fold 4 is: 0.597387162281829
# Our oof cohen kappa score is:  0.5923111288246463
# [0]	train-rmse:1.85641	val-rmse:1.85738
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.00835	val-rmse:1.16689
# [200]	train-rmse:0.723368	val-rmse:1.02641
# [300]	train-rmse:0.61223	val-rmse:1.00448
# [400]	train-rmse:0.552882	val-rmse:1.00018
# [500]	train-rmse:0.515885	val-rmse:0.999788
# [600]	train-rmse:0.487548	val-rmse:1.00029
# Stopping. Best iteration:
# [505]	train-rmse:0.514204	val-rmse:0.9997
#
# Partial score of fold 0 is: 0.5687679999676319
# [0]	train-rmse:1.85645	val-rmse:1.85755
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.0117	val-rmse:1.16492
# [200]	train-rmse:0.72593	val-rmse:1.01829
# [300]	train-rmse:0.610291	val-rmse:0.991171
# [400]	train-rmse:0.549352	val-rmse:0.987021
# [500]	train-rmse:0.509488	val-rmse:0.987634
# Stopping. Best iteration:
# [432]	train-rmse:0.534309	val-rmse:0.986863
#
# Partial score of fold 1 is: 0.5877350505914622
# [0]	train-rmse:1.85651	val-rmse:1.85763
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.00957	val-rmse:1.16163
# [200]	train-rmse:0.722424	val-rmse:1.01671
# [300]	train-rmse:0.612335	val-rmse:0.993015
# [400]	train-rmse:0.552783	val-rmse:0.990278
# [500]	train-rmse:0.513402	val-rmse:0.990892
# Stopping. Best iteration:
# [401]	train-rmse:0.55233	val-rmse:0.990253
#
# Partial score of fold 2 is: 0.580577672997564
# [0]	train-rmse:1.85638	val-rmse:1.85742
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.00798	val-rmse:1.1623
# [200]	train-rmse:0.728868	val-rmse:1.02032
# [300]	train-rmse:0.616261	val-rmse:0.996021
# [400]	train-rmse:0.556653	val-rmse:0.992874
# [500]	train-rmse:0.517663	val-rmse:0.993209
# Stopping. Best iteration:
# [402]	train-rmse:0.555659	val-rmse:0.992853
#
# Partial score of fold 3 is: 0.5823670173960386
# [0]	train-rmse:1.85645	val-rmse:1.85762
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.01094	val-rmse:1.16328
# [200]	train-rmse:0.730426	val-rmse:1.01766
# [300]	train-rmse:0.618823	val-rmse:0.992201
# [400]	train-rmse:0.560576	val-rmse:0.988203
# [500]	train-rmse:0.52339	val-rmse:0.987907
# Stopping. Best iteration:
# [483]	train-rmse:0.529144	val-rmse:0.98787
#
# Partial score of fold 4 is: 0.5884382216790691
# Our oof cohen kappa score is:  0.5826119203189382

# %%
lgb_model = Lgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals, params=LGB_BO.max['params'])
# Out:
# Found `n_estimators` in params. Will use it instead of argument
# Found `early_stopping_rounds` in params. Will use it instead of argument
# Using categorical_feature in Dataset.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.903286	valid_1's rmse: 0.998535
# [200]	training's rmse: 0.837168	valid_1's rmse: 0.992307
# [300]	training's rmse: 0.789364	valid_1's rmse: 0.992956
# Early stopping, best iteration is:
# [221]	training's rmse: 0.826152	valid_1's rmse: 0.991864
# Partial score of fold 0 is: 0.5803987385577165
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.905051	valid_1's rmse: 0.9843
# [200]	training's rmse: 0.839501	valid_1's rmse: 0.980207
# Early stopping, best iteration is:
# [159]	training's rmse: 0.862488	valid_1's rmse: 0.979469
# Partial score of fold 1 is: 0.5984304503424466
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.903711	valid_1's rmse: 0.98913
# [200]	training's rmse: 0.838095	valid_1's rmse: 0.982092
# [300]	training's rmse: 0.788168	valid_1's rmse: 0.982126
# Early stopping, best iteration is:
# [249]	training's rmse: 0.811666	valid_1's rmse: 0.980799
# Partial score of fold 2 is: 0.5957871003845977
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.907369	valid_1's rmse: 0.985881
# [200]	training's rmse: 0.840498	valid_1's rmse: 0.980384
# [300]	training's rmse: 0.791633	valid_1's rmse: 0.980156
# Early stopping, best iteration is:
# [255]	training's rmse: 0.812742	valid_1's rmse: 0.979451
# Partial score of fold 3 is: 0.600260461380784
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.905356	valid_1's rmse: 0.986461
# [200]	training's rmse: 0.84051	valid_1's rmse: 0.978775
# [300]	training's rmse: 0.792155	valid_1's rmse: 0.97831
# Early stopping, best iteration is:
# [289]	training's rmse: 0.797499	valid_1's rmse: 0.978155
# Partial score of fold 4 is: 0.5970292046577186
# Our oof cohen kappa score is:  0.5947090881231054

# %%
final_pred = lgb_model.y_pred

# %%
dist = Counter(reduce_train['accuracy_group'])
for k in dist:
    dist[k] /= len(reduce_train)
reduce_train['accuracy_group'].hist()

acum = 0
bound = {}
for i in range(3):
    acum += dist[i]
    bound[i] = np.percentile(final_pred, acum * 100)
print(bound)

def classify(x):
    if x <= bound[0]:
        return 0
    elif x <= bound[1]:
        return 1
    elif x <= bound[2]:
        return 2
    else:
        return 3
    
final_pred = np.array(list(map(classify, final_pred)))

sample_submission['accuracy_group'] = final_pred.astype(int)
sample_submission.to_csv('submission.csv', index=False)
sample_submission['accuracy_group'].value_counts(normalize=True)
# Out:
# {0: 1.5039054917168417, 1: 1.9304528579351816, 2: 2.1475476391183452}
# 3    0.500
# 0    0.239
# 1    0.136
# 2    0.125
# Name: accuracy_group, dtype: float64
